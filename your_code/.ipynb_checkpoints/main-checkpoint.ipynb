# %% [markdown]
# # Advanced Querying Mongo

# %%
import pandas as pd
import numpy as np
import pymongo
pd.options.display.max_columns = None

# %% [markdown]
# Importing libraries and setting up connection

# %%
cliente = pymongo.MongoClient()
cliente
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
cliente.list_database_names()
# Out:
# ['admin',
#  'config',
#  'lab_mongo',
#  'local',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata']

# %%
mydb = cliente["lab_mongo"]
coleccion = mydb.companies

# %%
pd.DataFrame(coleccion.find()).columns
# Out:
# Index(['_id', 'name', 'permalink', 'crunchbase_url', 'homepage_url',
#        'blog_url', 'blog_feed_url', 'twitter_username', 'category_code',
#        'number_of_employees', 'founded_year', 'founded_month', 'founded_day',
#        'deadpooled_year', 'tag_list', 'alias_list', 'email_address',
#        'phone_number', 'description', 'created_at', 'updated_at', 'overview',
#        'image', 'products', 'relationships', 'competitions', 'providerships',
#        'total_money_raised', 'funding_rounds', 'investments', 'acquisition',
#        'acquisitions', 'offices', 'milestones', 'video_embeds', 'screenshots',
#        'external_links', 'partners', 'deadpooled_month', 'deadpooled_day',
#        'deadpooled_url', 'ipo'],
#       dtype='object')

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
list(coleccion.find(({"name":"Babelgum"}), {"name":1,"_id":0}))
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
employee_size = pd.DataFrame((coleccion.find(({"number_of_employees":{"$gt": 5000}}), {"name":1, "_id":0, "number_of_employees":1}).sort("number_of_employees", -1).limit(20)))
index = pd.Index(range(1, 21))
employee_size = employee_size.set_index(index)
employee_size
# Out:
#                                           name  number_of_employees
# 1                                      Siemens               405000
# 2                                          IBM               388000
# 3                                       Toyota               320000
# 4                                       PayPal               300000
# 5   Nippon Telegraph and Telephone Corporation               227000
# 6                          Samsung Electronics               221726
# 7                                    Accenture               205000
# 8                    Tata Consultancy Services               200300
# 9                    Flextronics International               200000
# 10                                     Safeway               186000
# 11                                        Sony               180500
# 12                                          LG               177000
# 13                                        Ford               171000
# 14                                      Boeing               160000
# 15               Digital Equipment Corporation               140000
# 16                                       Nokia               125000
# 17                         MItsubishi Electric               107000
# 18                         MItsubishi Electric               107000
# 19                                 Bertelsmann               100000
# 20                                     Comcast               100000

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
cond1 = {"founded_year":{"$gte": 2000}}
cond2 = {"founded_year": {"$lte": 2005}}

list(coleccion.find({'$and': [cond1, cond2]}, {"name":1,"_id":0,"founded_year":1}).limit(5))
# Out:
# [{'name': 'Wetpaint', 'founded_year': 2005},
#  {'name': 'Zoho', 'founded_year': 2005},
#  {'name': 'Digg', 'founded_year': 2004},
#  {'name': 'Facebook', 'founded_year': 2004},
#  {'name': 'Omnidrive', 'founded_year': 2005}]

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
cond3 = {"ipo.valuation_amount":{"$gte": 100000000}}
cond4 = {"founded_year": {"$lte": 2010}}

list(coleccion.find({'$and': [cond3, cond4]}, {"name":1,"_id":0,"ipo.valuation_amount":1}).sort("ipo.valuation_amount",-1).limit(5))
# Out:
# [{'name': 'GREE', 'ipo': {'valuation_amount': 108960000000}},
#  {'name': 'Facebook', 'ipo': {'valuation_amount': 104000000000}},
#  {'name': 'Amazon', 'ipo': {'valuation_amount': 100000000000}},
#  {'name': 'Twitter', 'ipo': {'valuation_amount': 18100000000}},
#  {'name': 'Groupon', 'ipo': {'valuation_amount': 12800000000}}]

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
cond5 = {"number_of_employees":{"$lte": 1000}}
cond6 = {"founded_year": {"$lte": 2005}}

list(coleccion.find({'$and': [cond5, cond6]}, {"name":1,"_id":0,"number_of_employees":1}).sort("number_of_employees", -1).limit(10))
# Out:
# [{'name': 'Omniture', 'number_of_employees': 1000},
#  {'name': 'Telenav', 'number_of_employees': 1000},
#  {'name': 'Gumtree', 'number_of_employees': 1000},
#  {'name': 'SK Net Service Company Ltd', 'number_of_employees': 1000},
#  {'name': 'Yodle', 'number_of_employees': 1000},
#  {'name': "OC'LIANE", 'number_of_employees': 1000},
#  {'name': 'FANUC Robotics America', 'number_of_employees': 1000},
#  {'name': 'Antal International', 'number_of_employees': 1000},
#  {'name': 'Sonus Networks', 'number_of_employees': 1000},
#  {'name': 'Akamai Technologies', 'number_of_employees': 1000}]

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
sin_partner = list(coleccion.find({'partners':{'$exists':False}}, {"name":1,"_id":0})) #deberia funcionar, sin embargo los campos partners existen en todos los registros pero con listas vacias
print(sin_partner)
sin_partner = list(coleccion.find({'partners':{'$size':0}}, {"name":1, "partners":1, "_id":0}).limit(5)) #muestra un ejemplo de las compañias que no tienen partner y deberian estar incluidas en la lista anterior vacia
sin_partner
# Out:
# []
# [{'name': 'Wetpaint', 'partners': []},
#  {'name': 'AdventNet', 'partners': []},
#  {'name': 'Zoho', 'partners': []},
#  {'name': 'Digg', 'partners': []},
#  {'name': 'Facebook', 'partners': []}]

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
list(coleccion.find({"category_code": {"$type": "null"}}, {"_id":0,"category_code":1, "name":1}).limit(5))
# Out:
# [{'name': 'Collective', 'category_code': None},
#  {'name': 'Snimmer', 'category_code': None},
#  {'name': 'KoolIM', 'category_code': None},
#  {'name': 'Level9 Media', 'category_code': None},
#  {'name': 'VidKing', 'category_code': None}]

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
cond7 = {"number_of_employees":{"$gte": 100}}
cond8 = {"number_of_employees":{"$lt": 1000}}

list(coleccion.find({'$and': [cond7, cond8]}, {"name":1,"_id":0,"number_of_employees":1}).sort("number_of_employees", -1).limit(5))
# Out:
# [{'name': 'Datamonitor', 'number_of_employees': 984},
#  {'name': 'Infinera Corporation', 'number_of_employees': 974},
#  {'name': 'Box', 'number_of_employees': 950},
#  {'name': 'NorthPoint Communications Group', 'number_of_employees': 948},
#  {'name': '888 Holdings', 'number_of_employees': 931}]

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
ipo_price = pd.DataFrame((coleccion.find({"ipo.valuation_amount":{"$gte":1}},{"name":1,"_id":0,"ipo.valuation_amount":1}).sort("ipo.valuation_amount", -1)))
ipo_price.drop_duplicates(subset=['name']).head(5)
# Out:
#        name                                 ipo
# 0      GREE  {'valuation_amount': 108960000000}
# 1  Facebook  {'valuation_amount': 104000000000}
# 2    Amazon  {'valuation_amount': 100000000000}
# 3   Twitter   {'valuation_amount': 18100000000}
# 4   Groupon   {'valuation_amount': 12800000000}

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
list(coleccion.find({}, {"name":1,"_id":0,"number_of_employees":1}).sort("number_of_employees", -1).limit(10))
# Out:
# [{'name': 'Siemens', 'number_of_employees': 405000},
#  {'name': 'IBM', 'number_of_employees': 388000},
#  {'name': 'Toyota', 'number_of_employees': 320000},
#  {'name': 'PayPal', 'number_of_employees': 300000},
#  {'name': 'Nippon Telegraph and Telephone Corporation',
#   'number_of_employees': 227000},
#  {'name': 'Samsung Electronics', 'number_of_employees': 221726},
#  {'name': 'Accenture', 'number_of_employees': 205000},
#  {'name': 'Tata Consultancy Services', 'number_of_employees': 200300},
#  {'name': 'Flextronics International', 'number_of_employees': 200000},
#  {'name': 'Safeway', 'number_of_employees': 186000}]

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
list(coleccion.find({"founded_month":{"$gt":6}}, {"name":1,"_id":0,"founded_month":1}).limit(5))
# Out:
# [{'name': 'Wetpaint', 'founded_month': 10},
#  {'name': 'Zoho', 'founded_month': 9},
#  {'name': 'Digg', 'founded_month': 10},
#  {'name': 'Omnidrive', 'founded_month': 11},
#  {'name': 'eBay', 'founded_month': 9}]

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
cond9 = {"founded_year":{"$lt": 2000}}
cond10 = {"acquisition.price_amount":{"$gt": 1000000}}

pd.DataFrame(coleccion.find({'$and': [cond9, cond10]}, {"name":1,"_id":0,"founded_year":1, "acquisition.price_amount":1}).sort("acquisition.price_amount", -1).limit(8))
# Out:
#                      name  founded_year                   acquisition
# 0             BEA Systems          1995  {'price_amount': 8500000000}
# 1                  Navteq          1985  {'price_amount': 8100000000}
# 2        Sun Microsystems          1982  {'price_amount': 7400000000}
# 3                   Pixar          1986  {'price_amount': 7400000000}
# 4                     LSI          1980  {'price_amount': 6600000000}
# 5  National Semiconductor          1959  {'price_amount': 6500000000}
# 6               aQuantive          1997  {'price_amount': 6400000000}
# 7          Siebel Systems          1993  {'price_amount': 5850000000}

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
pd.DataFrame(coleccion.find({"acquisition.acquired_year":{"$gt":2010}}, 
                            {"name":1,
                             "_id":0,
                             "acquisition":1}).sort("acquisition.price_amount", -1).limit(5))
# Out:
#                      name                                        acquisition
# 0                T-Mobile  {'price_amount': 39000000000, 'price_currency_...
# 1    Goodrich Corporation  {'price_amount': 18400000000, 'price_currency_...
# 2                     LSI  {'price_amount': 6600000000, 'price_currency_c...
# 3  National Semiconductor  {'price_amount': 6500000000, 'price_currency_c...
# 4                   Ariba  {'price_amount': 4300000000, 'price_currency_c...

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
list(coleccion.find({"founded_year":{"$type":"number"}}, {"name":1, "_id":0, "founded_year":1}).sort("founded_year", 1).limit(5))
# Out:
# [{'name': 'Alstrasoft', 'founded_year': 1800},
#  {'name': 'SmallWorlds', 'founded_year': 1800},
#  {'name': 'US Army', 'founded_year': 1800},
#  {'name': 'DuPont', 'founded_year': 1802},
#  {'name': 'Bachmann Industries', 'founded_year': 1833}]

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
list(coleccion.find({"founded_day":{"$lte":7}}, {"acquisition.price_amount":1, "name":1, "_id":0}).sort("acquisition.price_amount", -1).limit(10))
# Out:
# [{'name': 'Netscape', 'acquisition': {'price_amount': 4200000000}},
#  {'name': 'PayPal', 'acquisition': {'price_amount': 1500000000}},
#  {'name': 'Zappos', 'acquisition': {'price_amount': 1200000000}},
#  {'name': 'Alibaba', 'acquisition': {'price_amount': 1000000000}},
#  {'name': 'Postini', 'acquisition': {'price_amount': 625000000}},
#  {'name': 'Danger', 'acquisition': {'price_amount': 500000000}},
#  {'name': 'Clearwell Systems', 'acquisition': {'price_amount': 410000000}},
#  {'name': 'PrimeSense', 'acquisition': {'price_amount': 345000000}},
#  {'name': 'Amobee', 'acquisition': {'price_amount': 321000000}},
#  {'name': 'Vitrue', 'acquisition': {'price_amount': 300000000}}]

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
list(coleccion.find({"category_code":"web"}, {"name":1, "category_code":1, "_id":0}).sort("number_of_employees", 1).limit(5))
# Out:
# [{'name': 'StumbleUpon', 'category_code': 'web'},
#  {'name': 'Gannett', 'category_code': 'web'},
#  {'name': 'Viacom', 'category_code': 'web'},
#  {'name': 'Gizmoz', 'category_code': 'web'},
#  {'name': 'Postini', 'category_code': 'web'}]

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
cond11 = {"acquisition.price_amount":{"$gt": 10000000}}
cond12 = {"acquisition.price_currency_code":"EUR"}

list(coleccion.find({"$and":[cond11, cond12]}, {"name":1, "_id":0}))
# Out:
# [{'name': 'ZYB'},
#  {'name': 'Apertio'},
#  {'name': 'Greenfield Online'},
#  {'name': 'Webedia'},
#  {'name': 'Wayfinder'},
#  {'name': 'Tuenti Technologies'},
#  {'name': 'BioMed Central'}]

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
list(coleccion.find({"acquisition.acquired_month":{"$lt":4}}, {"name":1, "_id":0, "acquisition":1}).limit(1))
# Out:
# [{'name': 'Kyte',
#   'acquisition': {'price_amount': None,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://techcrunch.com/2011/01/31/exclusive-kit-digital-acquires-kickapps-kewego-and-kyte-for-77-2-million/',
#    'source_description': 'KIT digital Acquires KickApps, Kewego AND Kyte For $77.2 Million',
#    'acquired_year': 2011,
#    'acquired_month': 1,
#    'acquired_day': 31,
#    'acquiring_company': {'name': 'KIT digital', 'permalink': 'kit-digital'}}}]

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
cond13 = {"founded_year":{"$gte":2000}}
cond14 = {"founded_year":{"$lt":2010}}
cond15 = {"acquisition.acquired_year":{"$gte":2011}}

pd.DataFrame(coleccion.find({'$and': [cond13, cond14, cond15]}, {"name":1,"_id":0, "founded_year":1, "acquisition.acquired_year":1}).limit(5))
# Out:
#               name  founded_year              acquisition
# 0         Wetpaint          2005  {'acquired_year': 2013}
# 1             Digg          2004  {'acquired_year': 2012}
# 2             Geni          2006  {'acquired_year': 2012}
# 3             Kyte          2006  {'acquired_year': 2011}
# 4  Jingle Networks          2005  {'acquired_year': 2011}

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
pd.DataFrame(coleccion.find()).sample(100)
# Out:
#                             _id                name           permalink  \
# 11230  52cdef7e4bab8bd67529a968               Magix               magix
# 8766   52cdef7d4bab8bd675299fc8        MediaUnbound        mediaunbound
# 9751   52cdef7e4bab8bd67529a3a1  Sanford Technology  sanford-technology
# 8028   52cdef7d4bab8bd675299ce6              Wayzon              wayzon
# 18618  52cdef7f4bab8bd67529c644   AddVal Technology   addval-technology
# ...                         ...                 ...                 ...
# 8818   52cdef7d4bab8bd675299ffc           JobeeHive           jobeehive
# 6780   52cdef7d4bab8bd675299806  LooseHead Software  loosehead-software
# 52     52cdef7c4bab8bd675297dbe             Stickam             stickam
# 953    52cdef7c4bab8bd675298143              IRSeeK              irseek
# 13434  52cdef7e4bab8bd67529b204               Uwink               uwink
#
#                                           crunchbase_url  \
# 11230            http://www.crunchbase.com/company/magix
# 8766      http://www.crunchbase.com/company/mediaunbound
# 9751   http://www.crunchbase.com/company/sanford-tech...
# 8028            http://www.crunchbase.com/company/wayzon
# 18618  http://www.crunchbase.com/company/addval-techn...
# ...                                                  ...
# 8818         http://www.crunchbase.com/company/jobeehive
# 6780   http://www.crunchbase.com/company/loosehead-so...
# 52             http://www.crunchbase.com/company/stickam
# 953             http://www.crunchbase.com/company/irseek
# 13434            http://www.crunchbase.com/company/uwink
#
#                        homepage_url                       blog_url  \
# 11230       http://www.magix.com/us
# 8766    http://www.mediaunbound.com  http://blog.mediaunbound.com/
# 9751                           None                           None
# 8028          http://www.wayzon.com
# 18618
# ...                             ...                            ...
# 8818       http://www.jobeehive.com  http://jobeehive.blogspot.com
# 6780   http://www.looseheadsoft.com
# 52           http://www.stickam.com   http://webmaster.stickam.com
# 953           http://www.irseek.com    http://www.irseek.com/blog/
# 13434          http://www.uwink.com
#
#                                            blog_feed_url twitter_username  \
# 11230                                                            Magix_NA
# 8766             http://blog.mediaunbound.com/?feed=rss2     mediaunbound
# 9751                                                None             None
# 8028                                                          brandbucket
# 18618
# ...                                                  ...              ...
# 8818   http://jobeehive.blogspot.com/feeds/posts/defa...             None
# 6780                                                                 None
# 52               http://blog.stickam.com/index.php/feed/          Stickam
# 953                http://www.irseek.com/blog/?feed=rss2             None
# 13434
#
#          category_code  number_of_employees  founded_year  founded_month  \
# 11230              web                  NaN           NaN            NaN
# 8766          software                 35.0        2000.0            1.0
# 9751              None                  NaN           NaN            NaN
# 8028   network_hosting                  NaN        2008.0            9.0
# 18618             None                  NaN        1996.0            NaN
# ...                ...                  ...           ...            ...
# 8818   network_hosting                  4.0        2007.0            9.0
# 6780            mobile                  6.0        2004.0            4.0
# 52         games_video                 35.0        2006.0            2.0
# 953             search                  NaN           NaN            NaN
# 13434      games_video                  NaN        1999.0            NaN
#
#        founded_day  deadpooled_year  \
# 11230          NaN              NaN
# 8766          21.0              NaN
# 9751           NaN              NaN
# 8028           NaN              NaN
# 18618          NaN              NaN
# ...            ...              ...
# 8818          12.0              NaN
# 6780          25.0              NaN
# 52             NaN           2013.0
# 953            NaN              NaN
# 13434          NaN              NaN
#
#                                                 tag_list alias_list  \
# 11230                                                          None
# 8766
# 9751                                                None       None
# 8028   social-tool, social-networking, web-2-o, netwo...       None
# 18618                                               None
# ...                                                  ...        ...
# 8818   employer-reviews-ratings, company-reviews, pro...       None
# 6780            mobile, social, social-network, wireless       None
# 52     video, livestream, webcam, live, livechat, cha...
# 953                               irc, ircsearch, nausea       None
# 13434                                               None
#
#                       email_address     phone_number  \
# 11230             info-us@magix.net   1-905-470-0400
# 8766         press@mediaunbound.com     617-621-0575
# 9751                           None             None
# 8028               press@wayzon.com
# 18618                                  408-861-1010
# ...                             ...              ...
# 8818          contact@jobeehive.com  +91-80-41607968
# 6780   blaine.nye@looseheadsoft.com     650.298.0209
# 52              support@stickam.com
# 953              info-us@bcasol.com   +972-9-9568644
# 13434                                   818-909-6030
#
#                                    description                    created_at  \
# 11230                                     None  Fri Dec 26 15:34:23 UTC 2008
# 8766   Personalization/recommendation software  Wed Oct 15 16:35:28 UTC 2008
# 9751                                      None  Wed Nov 19 17:11:18 UTC 2008
# 8028                                      None  Thu Sep 18 23:29:26 UTC 2008
# 18618  shipment-management products & services  Wed Jul 08 23:42:30 UTC 2009
# ...                                        ...                           ...
# 8818                                      None  Thu Oct 16 09:38:02 UTC 2008
# 6780                                      None  Sat Sep 06 01:27:16 UTC 2008
# 52                                              Thu Dec 20 10:07:40 UTC 2007
# 953                                       None  Mon Dec 03 14:16:38 UTC 2007
# 13434         entertainment restaurant company  Thu Feb 26 05:21:22 UTC 2009
#
#                          updated_at  \
# 11230  Sat Dec 27 16:24:21 UTC 2008
# 8766   Wed Aug 28 14:52:22 UTC 2013
# 9751   Thu Nov 20 01:06:07 UTC 2008
# 8028   Fri Jul 05 23:20:19 UTC 2013
# 18618  Sun Oct 24 13:03:03 UTC 2010
# ...                             ...
# 8818   Tue Feb 03 19:58:13 UTC 2009
# 6780   Thu Jul 04 21:45:51 UTC 2013
# 52     Sat Mar 16 09:55:43 UTC 2013
# 953    Wed Feb 13 20:32:53 UTC 2008
# 13434  Fri Nov 13 16:36:27 UTC 2009
#
#                                                 overview  \
# 11230  <p>MAGIX AG is an international provider of hi...
# 8766   <p>MediaUnbound, Inc., a software company, bui...
# 9751                                                None
# 8028   <p>The goal of The Wayzon Project is to simpli...
# 18618  <p>AddVal Technology, Inc. provides end-to-end...
# ...                                                  ...
# 8818   <p>JobeeHive is a professional-social network ...
# 6780   <p>LooseHead Software&#8217;s flagship product...
# 52     <p>Stickam.com is a social networking site tha...
# 953    <p>IRSeeK is an Israeli company indexing conve...
# 13434  <p>uWink, Inc. operates as an entertainment re...
#
#                                                    image  \
# 11230  {'available_sizes': [[[150, 59], 'assets/image...
# 8766   {'available_sizes': [[[150, 82], 'assets/image...
# 9751                                                None
# 8028   {'available_sizes': [[[150, 61], 'assets/image...
# 18618                                               None
# ...                                                  ...
# 8818   {'available_sizes': [[[150, 38], 'assets/image...
# 6780   {'available_sizes': [[[150, 44], 'assets/image...
# 52     {'available_sizes': [[[150, 27], 'assets/image...
# 953    {'available_sizes': [[[150, 33], 'assets/image...
# 13434  {'available_sizes': [[[150, 102], 'assets/imag...
#
#                                                 products  \
# 11230                                                 []
# 8766                                                  []
# 9751                                                  []
# 8028                                                  []
# 18618                                                 []
# ...                                                  ...
# 8818   [{'name': 'JobeeHive.com', 'permalink': 'jobee...
# 6780                                                  []
# 52     [{'name': 'Stickam', 'permalink': 'stickam'}, ...
# 953          [{'name': 'IRSeeK', 'permalink': 'irseek'}]
# 13434                                                 []
#
#                                            relationships  \
# 11230                                                 []
# 8766   [{'is_past': False, 'title': 'CEO, co-founder'...
# 9751                                                  []
# 8028   [{'is_past': False, 'title': 'Founder', 'perso...
# 18618                                                 []
# ...                                                  ...
# 8818   [{'is_past': False, 'title': 'Founder', 'perso...
# 6780   [{'is_past': False, 'title': 'CEO', 'person': ...
# 52     [{'is_past': False, 'title': 'Chairman', 'pers...
# 953    [{'is_past': None, 'title': 'CEO', 'person': {...
# 13434  [{'is_past': False, 'title': 'CEO', 'person': ...
#
#                                             competitions providerships  \
# 11230                                                 []            []
# 8766                                                  []            []
# 9751                                                  []            []
# 8028                                                  []            []
# 18618                                                 []            []
# ...                                                  ...           ...
# 8818   [{'competitor': {'name': 'Glassdoor', 'permali...            []
# 6780   [{'competitor': {'name': 'Weplay', 'permalink'...            []
# 52     [{'competitor': {'name': 'Ustream', 'permalink...            []
# 953                                                   []            []
# 13434                                                 []            []
#
#       total_money_raised                                     funding_rounds  \
# 11230              $155M  [{'id': 4293, 'round_code': 'unattributed', 's...
# 8766                  $0                                                 []
# 9751                  $0                                                 []
# 8028                  $0                                                 []
# 18618                 $0                                                 []
# ...                  ...                                                ...
# 8818                  $0                                                 []
# 6780               $500k  [{'id': 3384, 'round_code': 'angel', 'source_u...
# 52                    $0                                                 []
# 953                   $0                                                 []
# 13434                 $0                                                 []
#
#       investments                                        acquisition  \
# 11230          []                                               None
# 8766           []  {'price_amount': None, 'price_currency_code': ...
# 9751           []                                               None
# 8028           []                                               None
# 18618          []  {'price_amount': None, 'price_currency_code': ...
# ...           ...                                                ...
# 8818           []                                               None
# 6780           []                                               None
# 52             []                                               None
# 953            []                                               None
# 13434          []                                               None
#
#       acquisitions                                            offices  \
# 11230           []  [{'description': '', 'address1': '1105 Termina...
# 8766            []  [{'description': '', 'address1': '111 Rice Str...
# 9751            []                                                 []
# 8028            []                                                 []
# 18618           []  [{'description': 'HQ', 'address1': '1601 South...
# ...            ...                                                ...
# 8818            []  [{'description': 'JobeeHive', 'address1': '#66...
# 6780            []  [{'description': 'Headquarters', 'address1': '...
# 52              []  [{'description': '', 'address1': '1975 pads rd...
# 953             []  [{'description': None, 'address1': 'P.O.Box 58...
# 13434           []  [{'description': 'HQ', 'address1': '16106 Hart...
#
#       milestones video_embeds  \
# 11230         []           []
# 8766          []           []
# 9751          []           []
# 8028          []           []
# 18618         []           []
# ...          ...          ...
# 8818          []           []
# 6780          []           []
# 52            []           []
# 953           []           []
# 13434         []           []
#
#                                              screenshots  \
# 11230                                                 []
# 8766                                                  []
# 9751                                                  []
# 8028                                                  []
# 18618                                                 []
# ...                                                  ...
# 8818                                                  []
# 6780                                                  []
# 52                                                    []
# 953                                                   []
# 13434  [{'available_sizes': [[[150, 127], 'assets/ima...
#
#                                           external_links  \
# 11230                                                 []
# 8766   [{'external_url': 'http://gigaom.com/video/rov...
# 9751                                                  []
# 8028                                                  []
# 18618                                                 []
# ...                                                  ...
# 8818   [{'external_url': 'http://headstart.in/2008/10...
# 6780                                                  []
# 52                                                    []
# 953                                                   []
# 13434                                                 []
#
#                                                 partners  deadpooled_month  \
# 11230                                                 []               NaN
# 8766                                                  []               NaN
# 9751                                                  []               NaN
# 8028                                                  []               NaN
# 18618                                                 []               NaN
# ...                                                  ...               ...
# 8818                                                  []               NaN
# 6780   [{'partner_name': 'AngelList', 'homepage_url':...               NaN
# 52                                                    []               1.0
# 953                                                   []               NaN
# 13434                                                 []               NaN
#
#        deadpooled_day                                     deadpooled_url   ipo
# 11230             NaN                                               None  None
# 8766              NaN                                               None  None
# 9751              NaN                                               None  None
# 8028              NaN                                               None  None
# 18618             NaN                                               None  None
# ...               ...                                                ...   ...
# 8818              NaN                                               None  None
# 6780              NaN                                               None  None
# 52               31.0  http://blog.stickam.com/post/41909003713/stick...  None
# 953               NaN                                               None  None
# 13434             NaN                                               None  None
#
# [100 rows x 42 columns]

# %%
df_deadpooled = pd.DataFrame(coleccion.find({"deadpooled_year":{"$gt":0}},{"name":1, "_id":0, "deadpooled_year":1, "founded_year":1}))
df_deadpooled["creation_deadpool_years"] = df_deadpooled["deadpooled_year"] - df_deadpooled["founded_year"]
df_deadpooled[df_deadpooled["creation_deadpool_years"] > 3].sample(6)
# Out:
#                    name  founded_year  deadpooled_year  \
# 755             Foldees        2007.0             2011
# 41             Nirvanix        2007.0             2013
# 30         Hotelicopter        2006.0             2012
# 91               PlanHQ        2007.0             2013
# 408               Cucku        2007.0             2011
# 518  ConSentry Networks        2003.0             2011
#
#      creation_deadpool_years
# 755                      4.0
# 41                       6.0
# 30                       6.0
# 91                       6.0
# 408                      4.0
# 518                      8.0
