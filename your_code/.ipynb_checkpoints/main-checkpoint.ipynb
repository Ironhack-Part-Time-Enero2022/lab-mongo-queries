# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
import pymongo
import pandas as pd
import numpy as np

cliente = pymongo.MongoClient()
cliente
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
mybase = cliente.LABMONGO
coleccion = mybase.LABMONGO

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
# Your Code

pd.DataFrame(coleccion.find({"name":"Babelgum"}))
# Out:
#                         _id      name permalink  \
# 0  52cdef7c4bab8bd675297da0  Babelgum  babelgum
#
#                                crunchbase_url         homepage_url  \
# 0  http://www.crunchbase.com/company/babelgum  http://babelgum.com
#
#                    blog_url                         blog_feed_url  \
# 0  http://babelgum.com/blog  http://feeds.feedburner.com/Babelgum
#
#   twitter_username category_code number_of_employees  ...  investments  \
# 0         Babelgum   games_video                None  ...           []
#
#    acquisition  acquisitions  \
# 0         None            []
#
#                                              offices  milestones   ipo  \
# 0  [{'description': '', 'address1': '', 'address2...          []  None
#
#   video_embeds screenshots external_links partners
# 0           []          []             []       []
#
# [1 rows x 42 columns]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
# Your Code, Todas las empresas que tienen más de 5000 empleados. 
#Limite la búsqueda a 20 empresas y ordénelas por número de empleados.

pd.DataFrame(coleccion.find({"number_of_employees":{"$gt":5000}}))[:20]
# Out:
#                          _id                     name  \
# 0   52cdef7c4bab8bd675297d8e                 Facebook
# 1   52cdef7c4bab8bd675297d9b                     eBay
# 2   52cdef7c4bab8bd675297da2                    Cisco
# 3   52cdef7c4bab8bd675297da3                   Yahoo!
# 4   52cdef7c4bab8bd675297dba                   Google
# 5   52cdef7c4bab8bd675297dc4                    Intel
# 6   52cdef7c4bab8bd675297e49                 Nintendo
# 7   52cdef7c4bab8bd675297e5d            Adobe Systems
# 8   52cdef7c4bab8bd675297e6f                     Sony
# 9   52cdef7c4bab8bd675297e89                   PayPal
# 10  52cdef7c4bab8bd675297e8e  The Walt Disney Company
# 11  52cdef7c4bab8bd675297e96                      AOL
# 12  52cdef7c4bab8bd675297ea4                  Webkinz
# 13  52cdef7c4bab8bd675297ee9         Sun Microsystems
# 14  52cdef7c4bab8bd675297fc2                    Nokia
# 15  52cdef7c4bab8bd675297fcb                  Rakuten
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
# Your Code, Todas las empresas fundadas entre 2000 y 2005, ambos años incluidos. Recupere solo los campos namey .founded_year
#pd.DataFrame(coleccion.find({"founded_year":{"$in": ["2000", "2005"] }}, {"name"}))

condicion1={"founded_year":{"$gte":2000}}
condicion2={"founded_year":{"$lte":2005}}

query = {"$and":[condicion1,condicion2]}

pd.DataFrame(coleccion.find(query,{"_id":0,"name":1,"founded_year":1}).limit(5))
# Out:
#         name  founded_year
# 0   Wetpaint          2005
# 1       Zoho          2005
# 2       Digg          2004
# 3   Facebook          2004
# 4  Omnidrive          2005

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
# Your Code, todas las empresas que tuvieran un Importe de Valoración superior a 100.000.000 y hayan sido fundadas antes de 2010. 
#Recuperar únicamente los campos name y .ipo

cond1= {"founded_year":{"$lt":2010}}
cond2= {"ipo":{"$gte":["100.000.000"]}}
mix = {"$and":[condicion1,condicion2]}

pd.DataFrame(coleccion.find(mix,{"_id":0,"founded_year":1,"ipo":1}).limit(10))
# Out:
#    founded_year                                                ipo
# 0          2005                                                NaN
# 1          2005                                                NaN
# 2          2004                                               None
# 3          2004  {'valuation_amount': 104000000000, 'valuation_...
# 4          2005                                               None
# 5          2002                                               None
# 6          2003                                               None
# 7          2005                                               None
# 8          2002                                               None
# 9          2002                                               None

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
# Your Code,Todas las empresas que tengan menos de 1000 empleados y hayan sido fundadas antes de 2005. 
#Ordénalas por el número de empleados y limita la búsqueda a 10 empresas.

cond1= {"number_of_employees":{"$lt":1000}}
cond2= {"founded_year":{"$lt":2005}}

mix = {"$and":[condicion1,condicion2]}

pd.DataFrame(coleccion.find(mix,{"_id":0,"founded_year":1,"number_of_employees":1}).sort("number_of_employees",-1).limit(10))
# Out:
#    number_of_employees  founded_year
# 0               205000          2001
# 1                99999          2001
# 2                18000          2000
# 3                 8657          2005
# 4                 8000          2001
# 5                 5299          2004
# 6                 5000          2002
# 7                 4800          2003
# 8                 4000          2002
# 9                 2800          2003

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
# Your Code, todas las empresas que no incluyen el campo "partners".

pd.DataFrame(coleccion.find({'partner': {'$exists': False}}))[:5]
# Out:
#                         _id       name permalink  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint      abc2
# 1  52cdef7c4bab8bd675297d8b  AdventNet      abc3
# 2  52cdef7c4bab8bd675297d8c       Zoho      abc4
# 3  52cdef7c4bab8bd675297d8d       Digg      digg
# 4  52cdef7c4bab8bd675297d8e   Facebook  facebook
#
#                                 crunchbase_url             homepage_url  \
# 0   http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 1  http://www.crunchbase.com/company/adventnet     http://adventnet.com
# 2       http://www.crunchbase.com/company/zoho          http://zoho.com
# 3       http://www.crunchbase.com/company/digg      http://www.digg.com
# 4   http://www.crunchbase.com/company/facebook      http://facebook.com
#
#                       blog_url                      blog_feed_url  \
# 0  http://digitalquarters.net/   http://digitalquarters.net/feed/
# 1
# 2       http://blogs.zoho.com/         http://blogs.zoho.com/feed
# ...

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
# Your Code,Todas las empresas que contengan nulos en "category_code"


pd.DataFrame(coleccion.find({"category_code": {"$type": "null"}},{"_id":0, "category_code":1}))[:10]
# Out:
#   category_code
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None
# 8          None
# 9          None

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
# Your Code,todas las empresas que tienen al menos 100 empleados pero menos de 1000. 
#Recuperar solo los campos "name" y "number of employees".

cond1= {"number_of_employees":{"$gte":100}}
cond2= {"number_of_employees":{"$lte":1000}}
mix= {"$and":[cond1,cond2]}

pd.DataFrame(coleccion.find(mix,{"_id":0,"name":1,"number_of_employees":1}).sort("ipo",-1))[:10]
# Out:
#                    name  number_of_employees
# 0                  GREE                  700
# 1                Zillow                  600
# 2                  Yelp                  800
# 3            Higher One                  380
# 4             OpenTable                  550
# 5              QlikTech                  600
# 6      Millennial Media                  137
# 7                  Mixi                  257
# 8  Cornerstone OnDemand                  881
# 9              Infoblox                  500

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
# Your Code, ordenar todas las compañías por el IPO en orden descendiente.

list(coleccion.find({"_id":0,"ipo":1}).sort("ipo",-1))
# Out:
# []

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
# Your Code,dar una lista con los nombres de las 10 empresas con más empleados:

list(coleccion.find({"_id":0,"name":1,"number_of_employees":1}).sort("number_of_employees",-1))[:10]
# Out:
# []

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
# Your Code	

founded_year

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
# Your Code,todas las empresas fundadas antes del 2000 que tengan un monto de adquisición superior a 10.000.000, #{"founded_year":{"$lt":2000}},"ipo":"$gt":10.000.00}

cond1= {"founded_year":{"$lt":2000}}
cond2= {"ipo":{"$gt":10000000}}
       
mix= {"$and":[cond1,cond2]}
       
list(coleccion.find(mix,{"_id":0,"founded_year":1,"ipo":1}))
# Out:
# []

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
#Todas las empresas que han sido adquiridas después de 2010, 
#se ordenan por el monto de la adquisición y recuperan solo su campo namey acquisition.


list(coleccion.find({"acquisition":{"$gte":2010}},{"_id":0,"name":1,"acquisition":1}).sort("ipo",-1))
# Out:
# []

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
# Your Code
list(coleccion.find({"_id":0,"name":1,"founded_year":1}).sort("founded_year",-1))
# Out:
# []

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
# Your Code

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
# Your Code

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
# Your Code

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
# Your Code

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
# Your Code

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
# Your Code
