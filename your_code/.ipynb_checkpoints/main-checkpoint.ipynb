# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
# from pymongo import MongoClient
# client = MongoClient("")

import pymongo
import pandas as pd

cliente = pymongo.MongoClient()

cliente.list_database_names()

mydb = cliente['Ironhack']

comp = mydb.Companies

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
# Your Code
name_babelgum = list(comp.find({'name' : 'Babelgum'}, {'name' : 1, '_id' :0})) #No comprendo bien que únicamente te manden devolder el name, porque si hay más de una y buscas por nombre todos serán Balbegum.

name_babelgum
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
# Your Code
companies_big = list(comp.find({'number_of_employees': {"$gte": 5000}}).sort("number_of_employees", 1).limit(20))

companies_big[:1]
# Out:
# [{'_id': ObjectId('52cdef7e4bab8bd67529aa77'),
#   'name': 'JDS Uniphase Corporation',
#   'permalink': 'jds-uniphase-corporation',
#   'crunchbase_url': 'http://www.crunchbase.com/company/jds-uniphase-corporation',
#   'homepage_url': 'http://www.jdsu.com',
#   'blog_url': 'http://blogs.jdsu.com/perspectives/default.aspx',
#   'blog_feed_url': 'http://feeds.feedburner.com/JdsuPerspectivesPosts',
#   'twitter_username': 'JDSU',
#   'category_code': 'hardware',
#   'number_of_employees': 5000,
#   'founded_year': None,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': '',
#   'alias_list': '',
#   'email_address': '',
#   'phone_number': '+1 408 546 5000',
#   'description': '',
#   'created_at': 'Sat Jan 03 04:11:21 UTC 2009',
#   'updated_at': 'Thu Dec 12 04:51:28 UTC 2013',
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
# Your Code
cond1 = {'founded_year':{'$gte' : 2000}}
cond2 = {'founded_year': {"$lte": 2005}}

founded_year = list(comp.find({'$and': [cond1, cond2]}, {'name' : 1, 'founded_year' : 1, '_id' : 0}))
founded_year[:2]
# Out:
# [{'name': 'Wetpaint', 'founded_year': 2005},
#  {'name': 'Zoho', 'founded_year': 2005}]

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
# Your Code
cond1 = {'ipo.valuation_amount':{'$gt' : 100000000}}
cond2 = {'founded_year': {"$lt": 2010}}

founded_year = list(comp.find({'$and': [cond1, cond2]}, {'name' : 1, 'ipo' : 1, '_id' : 0}))
founded_year[:2]
# Out:
# [{'name': 'Facebook',
#   'ipo': {'valuation_amount': 104000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 5,
#    'pub_day': 18,
#    'stock_symbol': 'NASDAQ:FB'}},
#  {'name': 'Twitter',
#   'ipo': {'valuation_amount': 18100000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2013,
#    'pub_month': 11,
#    'pub_day': 7,
#    'stock_symbol': 'NYSE:TWTR'}}]

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
# Your Code
cond51 = {'number_of_employees':{'$gt':1000}}
cond52 = {'founded_year': {"$lt": 2005}}

ejerc_5 =list(comp.find({'$and': [cond51, cond52]}).sort("number_of_employees", 1).limit(10))
ejerc_5[:1]
# Out:
# [{'_id': ObjectId('52cdef7f4bab8bd67529c5fa'),
#   'name': 'MSC Software',
#   'permalink': 'msc-software',
#   'crunchbase_url': 'http://www.crunchbase.com/company/msc-software',
#   'homepage_url': 'http://www.mscsoftware.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': '',
#   'category_code': 'software',
#   'number_of_employees': 1006,
#   'founded_year': 1963,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': '',
#   'alias_list': '',
#   'email_address': '',
#   'phone_number': '714-540-8900',
#   'description': 'Simulation Software',
#   'created_at': 'Wed Jul 08 20:48:15 UTC 2009',
#   'updated_at': 'Wed Jul 15 02:18:28 UTC 2009',
# ...

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
# Your Code
partners_no = list(comp.find({'partners': {'$exists': False}}))
partners_no[:2]
# Out:
# []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
# Your Code
null_ = list(comp.find({"category_code": {"$type": "null"}}))
null_[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd6752980f6'),
#   'name': 'Collective',
#   'permalink': 'collective',
#   'crunchbase_url': 'http://www.crunchbase.com/company/collective',
#   'homepage_url': None,
#   'blog_url': None,
#   'blog_feed_url': None,
#   'twitter_username': None,
#   'category_code': None,
#   'number_of_employees': None,
#   'founded_year': None,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': None,
#   'alias_list': None,
#   'email_address': None,
#   'phone_number': None,
#   'description': None,
#   'created_at': 'Thu Sep 26 13:15:02 UTC 2013',
#   'updated_at': 'Thu Sep 26 13:15:02 UTC 2013',
#   'overview': None,
#   'image': None,
#   'products': [],
#   'relationships': [],
#   'competitions': [],
#   'providerships': [],
#   'total_money_raised': '$0',
#   'funding_rounds': [],
#   'investments': [],
#   'acquisition': None,
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
# Your Code
cond81 = {'number_of_employees':{'$gte':100}}
cond82 = {'number_of_employees': {"$lte": 1000}}

ejerc_8 = list(comp.find({'$and': [cond81, cond82]}, {'name' : 1, 'number_of_employees' : 1, '_id' : 0}))
ejerc_8[:1]
# Out:
# [{'name': 'AdventNet', 'number_of_employees': 600}]

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
# Your Code
ipo_price = list(comp.find().sort("ipo.valuation_amount", -1))
ipo_price[:1]
# Out:
# [{'_id': ObjectId('52cdef7e4bab8bd67529a8b4'),
#   'name': 'GREE',
#   'permalink': 'gree',
#   'crunchbase_url': 'http://www.crunchbase.com/company/gree',
#   'homepage_url': 'http://www.gree-corp.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': 'gree_corp',
#   'category_code': 'games_video',
#   'number_of_employees': 700,
#   'founded_year': 2004,
#   'founded_month': 12,
#   'founded_day': 7,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'mobile-web, japan, tokyo, social-network, mobile-social-network, mobile-games',
#   'alias_list': None,
#   'email_address': 'inquiry@gree-corp.com',
#   'phone_number': '',
#   'description': 'Internet media business,SNS,  free game',
#   'created_at': 'Sat Dec 20 16:42:57 UTC 2008',
#   'updated_at': 'Tue Jan 01 21:37:04 UTC 2013',
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
# Your Code
big_companies = list(comp.find().sort('number_of_employees', -1).limit(10))
big_companies[:1]
# Out:
# [{'_id': ObjectId('52cdef7d4bab8bd67529941a'),
#   'name': 'Siemens',
#   'permalink': 'siemens',
#   'crunchbase_url': 'http://www.crunchbase.com/company/siemens',
#   'homepage_url': 'http://www.siemens.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': 'Siemens',
#   'category_code': 'hardware',
#   'number_of_employees': 405000,
#   'founded_year': 1847,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'automation, building-technologies, drive-technology, energy',
#   'alias_list': '',
#   'email_address': 'contact@siemens.com',
#   'phone_number': '49 89 636 34134',
#   'description': 'Electronics and Electrical Engineering',
#   'created_at': 'Thu Jul 31 09:29:43 UTC 2008',
#   'updated_at': 'Thu Nov 28 20:32:55 UTC 2013',
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
# Your Code
second_companies = list(comp.find({'founded_month' : {'$gt' : 6}}).limit(1000))
second_companies[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d8a'),
#   'name': 'Wetpaint',
#   'permalink': 'abc2',
#   'crunchbase_url': 'http://www.crunchbase.com/company/wetpaint',
#   'homepage_url': 'http://wetpaint-inc.com',
#   'blog_url': 'http://digitalquarters.net/',
#   'blog_feed_url': 'http://digitalquarters.net/feed/',
#   'twitter_username': 'BachelrWetpaint',
#   'category_code': 'web',
#   'number_of_employees': 47,
#   'founded_year': 2005,
#   'founded_month': 10,
#   'founded_day': 17,
#   'deadpooled_year': 1,
#   'tag_list': 'wiki, seattle, elowitz, media-industry, media-platform, social-distribution-system',
#   'alias_list': '',
#   'email_address': 'info@wetpaint.com',
#   'phone_number': '206.859.6300',
#   'description': 'Technology Platform Company',
#   'created_at': datetime.datetime(2007, 5, 25, 6, 51, 27),
#   'updated_at': 'Sun Dec 08 07:15:44 UTC 2013',
# ...

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
# Your Code
cond121 = {'founded_year' : {'$lt' : 2000}}
cond122 = {'acquisition.price_amount' : {'$gt' : 1000000}}

comp_12 = list(comp.find({'$and': [cond121, cond122]}))
comp_12[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d90'),
#   'name': 'Postini',
#   'permalink': 'postini',
#   'crunchbase_url': 'http://www.crunchbase.com/company/postini',
#   'homepage_url': 'http://postini.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': None,
#   'category_code': 'web',
#   'number_of_employees': None,
#   'founded_year': 1999,
#   'founded_month': 6,
#   'founded_day': 2,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': '',
#   'alias_list': None,
#   'email_address': '',
#   'phone_number': '888.584.3150',
#   'description': None,
#   'created_at': 'Fri Jun 08 12:19:51 UTC 2007',
#   'updated_at': 'Sat Aug 13 18:02:34 UTC 2011',
# ...

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
# Your Code
comp_acq = list(comp.find({'acquisition.acquired_year' : {'$gt' : 2010}}, {'name' : 1, 'acquisition' : 1, '_id' : 0}).sort('acquisition.price_amount', 1))
comp_acq[:1]
# Out:
# [{'name': 'Geni',
#   'acquisition': {'price_amount': None,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://techcrunch.com/2012/11/28/all-in-the-family-myheritage-buys-former-yammer-stablemate-geni-com-raises-25m/',
#    'source_description': 'MyHeritage acquires Geni and $25M to build family tree of the whole world',
#    'acquired_year': 2012,
#    'acquired_month': 11,
#    'acquired_day': 28,
#    'acquiring_company': {'name': 'MyHeritage', 'permalink': 'myheritage'}}}]

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
# Your Code
comp_founded = list(comp.find({}, {'name' : 1, 'founded_year' : 1, '_id' : 0}).sort('founded_year', -1))
comp_founded[:1]
# Out:
# [{'name': 'Fixya', 'founded_year': 2013}]

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
# Your Code
comp_10 = list(comp.find({'founded_month' : {'$lte' : 7}}).sort('acquisition.price_amount', -1).limit(10))
comp_10[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297ee9'),
#   'name': 'Sun Microsystems',
#   'permalink': 'sun-microsystems',
#   'crunchbase_url': 'http://www.crunchbase.com/company/sun-microsystems',
#   'homepage_url': 'http://www.sun.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': 'sunmicrosystems',
#   'category_code': 'enterprise',
#   'number_of_employees': 33350,
#   'founded_year': 1982,
#   'founded_month': 2,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'vendor, computer, hardware, software',
#   'alias_list': 'Sun',
#   'email_address': '',
#   'phone_number': '1-800-786-0404',
#   'description': 'Computer Hardware and Software Provider',
#   'created_at': 'Sat Aug 18 08:52:54 UTC 2007',
#   'updated_at': 'Thu Mar 14 14:41:26 UTC 2013',
# ...

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
# Your Code

comp_web = list(comp.find({'category_code' : 'web', 'number_of_employees' : {'$gt' : 4000}}).sort('number_of_employees', 1))
comp_web[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd67529822a'),
#   'name': 'Expedia',
#   'permalink': 'expedia',
#   'crunchbase_url': 'http://www.crunchbase.com/company/expedia',
#   'homepage_url': 'http://www.expedia.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': 'Expedia',
#   'category_code': 'web',
#   'number_of_employees': 4400,
#   'founded_year': 1996,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'travel, flights, hotels, tickets, airline, vacation, travel-comparison, travel-search',
#   'alias_list': '',
#   'email_address': '',
#   'phone_number': '1-800-EXPEDIA',
#   'description': '',
#   'created_at': 'Sun Feb 10 03:29:12 UTC 2008',
#   'updated_at': 'Sun Dec 08 07:03:33 UTC 2013',
# ...

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
# Your Code
comp_eur = list(comp.find({'acquisition.price_currency_code' : 'EUR', 'acquisition.price_amount' : {'$gt' : 10000000}}))
comp_eur[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297f02'),
#   'name': 'ZYB',
#   'permalink': 'zyb',
#   'crunchbase_url': 'http://www.crunchbase.com/company/zyb',
#   'homepage_url': 'http://zyb.com',
#   'blog_url': 'http://blog.zyb.com/',
#   'blog_feed_url': 'http://blog.zyb.com/index.php/feed/',
#   'twitter_username': None,
#   'category_code': 'mobile',
#   'number_of_employees': 25,
#   'founded_year': None,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'mobile, social-networking, socialnetwork',
#   'alias_list': '',
#   'email_address': 'contact@zyb.com',
#   'phone_number': '',
#   'description': 'Mobile Social Networking',
#   'created_at': 'Wed Aug 22 05:14:51 UTC 2007',
#   'updated_at': 'Tue Jul 02 03:00:50 UTC 2013',
# ...

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
# Your Code
comp_acqu_first = list(comp.find({'acquisition.acquired_month' : {'$lte' : 3}}, {'name' : 1, 'acquisition' : 1, '_id' : 0}).limit(10))
comp_acqu_first[:1]
# Out:
# [{'name': 'Kyte',
#   'acquisition': {'price_amount': None,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://techcrunch.com/2011/01/31/exclusive-kit-digital-acquires-kickapps-kewego-and-kyte-for-77-2-million/',
#    'source_description': 'KIT digital Acquires KickApps, Kewego AND Kyte For $77.2 Million',
#    'acquired_year': 2011,
#    'acquired_month': 1,
#    'acquired_day': 31,
#    'acquiring_company': {'name': 'KIT digital', 'permalink': 'kit-digital'}}}]

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
# Your Code
cond191 = {'founded_year' : {'$gte' : 2000}}
cond192 = {'founded_year': {"$lte": 2010}}
cond193 = {'acquisition.acquired_year' : {'$gt' : 2011}}

comp_19 = list(comp.find({'$and': [cond191 , cond192 , cond193]}))
comp_19[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d8a'),
#   'name': 'Wetpaint',
#   'permalink': 'abc2',
#   'crunchbase_url': 'http://www.crunchbase.com/company/wetpaint',
#   'homepage_url': 'http://wetpaint-inc.com',
#   'blog_url': 'http://digitalquarters.net/',
#   'blog_feed_url': 'http://digitalquarters.net/feed/',
#   'twitter_username': 'BachelrWetpaint',
#   'category_code': 'web',
#   'number_of_employees': 47,
#   'founded_year': 2005,
#   'founded_month': 10,
#   'founded_day': 17,
#   'deadpooled_year': 1,
#   'tag_list': 'wiki, seattle, elowitz, media-industry, media-platform, social-distribution-system',
#   'alias_list': '',
#   'email_address': 'info@wetpaint.com',
#   'phone_number': '206.859.6300',
#   'description': 'Technology Platform Company',
#   'created_at': datetime.datetime(2007, 5, 25, 6, 51, 27),
#   'updated_at': 'Sun Dec 08 07:15:44 UTC 2013',
# ...

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
# Your Code
comp_deadpooled = list(comp.find({'deadpooled_year' : {'$gt' : 3}}))
comp_deadpooled[:1]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d8f'),
#   'name': 'Omnidrive',
#   'permalink': 'omnidrive',
#   'crunchbase_url': 'http://www.crunchbase.com/company/omnidrive',
#   'homepage_url': 'http://www.omnidrive.com',
#   'blog_url': 'http://www.omnidrive.com/blog',
#   'blog_feed_url': 'http://feeds.feedburner.com/omnidrive',
#   'twitter_username': 'Nomadesk',
#   'category_code': 'network_hosting',
#   'number_of_employees': None,
#   'founded_year': 2005,
#   'founded_month': 11,
#   'founded_day': 1,
#   'deadpooled_year': 2008,
#   'deadpooled_month': 9,
#   'deadpooled_day': 15,
#   'deadpooled_url': '',
#   'tag_list': 'storage, sharing, edit, online',
#   'alias_list': None,
#   'email_address': 'info@omnidrive.com',
#   'phone_number': '660-675-5052',
#   'description': None,
#   'created_at': 'Sun May 27 03:25:32 UTC 2007',
#   'updated_at': 'Tue Jul 02 22:48:04 UTC 2013',
# ...
