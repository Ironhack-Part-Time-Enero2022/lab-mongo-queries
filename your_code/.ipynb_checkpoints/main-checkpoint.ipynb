# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
from pymongo import MongoClient
import pandas as pd
client = MongoClient()

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
mydb = client["mongo_lab"]
collection = mydb.mongo_lab_collection

list(collection.find({"name":"Babelgum"}).distinct("name"))
# Out:
# ['Babelgum']

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
companies_gt_5000 = pd.DataFrame(collection.find({'number_of_employees': {"$gte": 5000}}))[:20]
companies_gt_5000.sort_values(by=["number_of_employees"])
# Out:
#                          _id                     name  \
# 6   52cdef7c4bab8bd675297e49                 Nintendo
# 0   52cdef7c4bab8bd675297d8e                 Facebook
# 7   52cdef7c4bab8bd675297e5d            Adobe Systems
# 18  52cdef7c4bab8bd6752981b5                   NetApp
# 11  52cdef7c4bab8bd675297e96                      AOL
# 12  52cdef7c4bab8bd675297ea4                  Webkinz
# 15  52cdef7c4bab8bd675297fcb                  Rakuten
# 3   52cdef7c4bab8bd675297da3                   Yahoo!
# 1   52cdef7c4bab8bd675297d9b                     eBay
# 10  52cdef7c4bab8bd675297e8e  The Walt Disney Company
# 4   52cdef7c4bab8bd675297dba                   Google
# 13  52cdef7c4bab8bd675297ee9         Sun Microsystems
# 19  52cdef7c4bab8bd67529821b       Motorola Solutions
# 2   52cdef7c4bab8bd675297da2                    Cisco
# 17  52cdef7c4bab8bd675298189                    Apple
# 5   52cdef7c4bab8bd675297dc4                    Intel
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
cond1 = {'founded_year': {"$gte": 2000}}
cond2 = {'founded_year': {"$gte": 2005}}

data = collection.find({'$and': [cond1, cond2]}, 
                       {"_id":0,"name":1,"founded_year":1}
                      )

companies_founded_00_05 = pd.DataFrame(data)
companies_founded_00_05
# Out:
#             name  founded_year
# 0       Wetpaint          2005
# 1           Zoho          2005
# 2      Omnidrive          2005
# 3           Geni          2006
# 4        Twitter          2006
# ...          ...           ...
# 7964  Eazeeloans          2006
# 7965     DocASAP          2012
# 7966    cotralis          2008
# 7967      Oriact          2009
# 7968      Adhunk          2009
#
# [7969 rows x 2 columns]

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
cond1 = {'ipo.valuation_amount': {"$gte": 100000000}}
cond2 = {'founded_year': {"$gte": 2010}}

data = collection.find({'$and': [cond1, cond2]}, 
                       {"_id":0,"ipo":1,"name":1}
                      )[:20]

companies_founded_10_amount_100M = pd.DataFrame(data)
companies_founded_10_amount_100M
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
cond1 = {'number_of_employees': {"$lte": 1000}}
cond2 = {'founded_year': {"$gte": 2005}}

data = collection.find({'$and': [cond1, cond2]}, 
                       {"_id":0,"name":1,"number_of_employees":1}
                      )

companies_5 = pd.DataFrame(data).sort_values(by=["name"],ascending=True).sort_values(by=["number_of_employees"],ascending=False)[:10]
companies_5
# Out:
#                          name  number_of_employees
# 1758             Yatra online                 1000
# 3974             Hello Travel                 1000
# 3734             Brain Bakery                 1000
# 5607       JinkoSolar Holding                 1000
# 2813                  Gumtree                 1000
# 326                     Yodle                 1000
# 50                        Box                  950
# 902                    InMobi                  900
# 646                   Workday                  900
# 3930  Relax Solutions Pvt Ltd                  900

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
data = collection.find({'partners': {'$exists': False}},
                       {"_id":0,"name":1}
                      )

companies_6 = pd.DataFrame(data)
companies_6
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
data = collection.find({"category_code": {"$type": "null"}},
                       {"_id":0,"name":1}
                      )

companies_7 = pd.DataFrame(data)
companies_7
# Out:
#               name
# 0       Collective
# 1          Snimmer
# 2           KoolIM
# 3     Level9 Media
# 4          VidKing
# ...            ...
# 2746        Nellix
# 2747      Cantimer
# 2748  cruisecritic
# 2749      Coloroot
# 2750      Geekdive
#
# [2751 rows x 1 columns]

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
cond1 = {'number_of_employees': {"$lte": 1000}}
cond2 = {'number_of_employees': {"$gte": 100}}

data = collection.find({'$and': [cond1, cond2]}, 
                       {"_id":0,"name":1,"number_of_employees":1}
                      )

companies_8 = pd.DataFrame(data)
companies_8
# Out:
#                       name  number_of_employees
# 0                AdventNet                  600
# 1                  AddThis                  120
# 2                    OpenX                  305
# 3                 LifeLock                  644
# 4                    Jajah                  110
# ..                     ...                  ...
# 937  UOL (Universo Online)                  500
# 938               NextLabs                  100
# 939      OfficialVirtualDJ                  102
# 940          Willdan Group                  385
# 941                   QSGI                  164
#
# [942 rows x 2 columns]

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
data = collection.find(
{"_id":0,"name":1,"ipo.price":1}
)

companies_9 = pd.DataFrame(data)
companies_9
#no me sale
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
data = collection.find(
                       {"_id":0,"name":1,"number_of_employees":1}
                      ).sort("number_of_employees", -1).limit(10)

companies_10 = pd.DataFrame(data)
companies_10
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
cond1 = {'founded_month': {"$lte": 12}}
cond2 = {'founded_month': {"$gte": 7}}

data = collection.find({'$and': [cond1, cond2]}, 
                       {"_id":0,"name":1}
                      )

companies_11 = pd.DataFrame(data)[:1000]
companies_11
# Out:
#              name
# 0        Wetpaint
# 1            Zoho
# 2            Digg
# 3       Omnidrive
# 4            eBay
# ..            ...
# 995      LingusTV
# 996  AccountMaven
# 997      Chapatiz
# 998       YOOWALK
# 999   Data Domain
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
cond1 = {'acquisition.price_amount': {"$gte": 1000000}}
cond2 = {'founded_year': {"$gte": 2000}}

data = collection.find({'$and': [cond1, cond2]}, 
                       {"_id":0,"name":1}
                      )

companies_12 = pd.DataFrame(data)
companies_12
# Out:
#                      name
# 0                Wetpaint
# 1             StumbleUpon
# 2                   Helio
# 3                   Plaxo
# 4                Powerset
# ..                    ...
# 329  Mu-Gahat Enterprises
# 330       Luminus Devices
# 331        EnterSys Group
# 332               Intergy
# 333             EnteGreat
#
# [334 rows x 1 columns]

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
cond1 = {'founded_year': {"$gte": 2010}}

data = collection.find({'$and': [cond1]}, 
                       {"_id":0,"name":1,"acquisition":1}
                      ).sort("price_amount", 1)
companies_13 = pd.DataFrame(data)
companies_13
# Out:
#              name acquisition
# 0        Mokitown        None
# 1        CircleUp        None
# 2         PeekYou        None
# 3           GENWI        None
# 4           headr        None
# ..            ...         ...
# 141       Shreppy        None
# 142  Start Mobile        None
# 143       Pitchie        None
# 144     Treehouse        None
# 145       DocASAP        None
#
# [146 rows x 2 columns]

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
data = collection.find(
                       {"_id":0,"name":1,"founded_year":1}
                      ).sort("founded_year", 1)
companies_14 = pd.DataFrame(data)
companies_14
#no me sale
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
cond1 = {'founded_day': {"$gte": 1}}
cond2 = {'founded_day': {"$lte": 7}}

data = collection.find({'$and': [cond1, cond2]}, 
                       {"_id":0,"name":1,"acquisition_price":1}
                      ).sort("acquisition_price", -1).limit(10)

companies_15 = pd.DataFrame(data)
companies_15
# Out:
#                     name
# 0            StumbleUpon
# 1                  Joost
# 2                Postini
# 3                 Gizmoz
# 4                   eBay
# 5  Fox Interactive Media
# 6               Facebook
# 7              Omnidrive
# 8                   Geni
# 9                  Helio

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
cond1 = {'category_code': 'web'}
cond2 = {'number_of_employees': {"$lte": 4000}}

data = collection.find({'$and': [cond1, cond2]}, 
                       {"_id":0,"name":1,"acquisition_price":1}
                      ).sort("number_of_employees", 1)

companies_16 = pd.DataFrame(data)
companies_16
# Out:
#                        name
# 0     Fox Interactive Media
# 1                    coRank
# 2                      Bebo
# 3              Ticketmaster
# 4                  Go2Web20
# ...                     ...
# 2065                Mozilla
# 2066                Gumtree
# 2067            HomeAdvisor
# 2068                 Zappos
# 2069    Daum Communications
#
# [2070 rows x 1 columns]

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
cond1 = {'acquisition.price_currency_code': 'EUR'}
cond2 = {'acquisition.price_amount': {"$gte": 10000000}}

data = collection.find({'$and': [cond1, cond2]}, 
                       {"_id":0,"name":1}
                      )
companies_17 = pd.DataFrame(data)
companies_17
#no me sale
# Out:
#                   name
# 0                  ZYB
# 1              Apertio
# 2    Greenfield Online
# 3              Webedia
# 4            Wayfinder
# 5  Tuenti Technologies
# 6       BioMed Central

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
cond1 = {'acquisition.acquired_month': {"$lte": 3}}
cond2 = {'acquisition.acquired_month': {"$gte": 1}}

data = collection.find({'$and': [cond1, cond2]}, 
                       {"_id":0,"acquisition":1, "name":1}
                      )
companies_18 = pd.DataFrame(data)
companies_18
#no me sale
# Out:
#                             name  \
# 0                           Kyte
# 1                     NetRatings
# 2                         blogTV
# 3                     Livestream
# 4                       iContact
# ..                           ...
# 637  Advanced Control Components
# 638      Celestial Semiconductor
# 639              InSound Medical
# 640               EnterSys Group
# 641                      Intergy
#
#                                            acquisition
# 0    {'price_amount': None, 'price_currency_code': ...
# 1    {'price_amount': 327000000, 'price_currency_co...
# 2    {'price_amount': None, 'price_currency_code': ...
# 3    {'price_amount': None, 'price_currency_code': ...
# 4    {'price_amount': 169000000, 'price_currency_co...
# ..                                                 ...
# 637  {'price_amount': 18780000, 'price_currency_cod...
# 638  {'price_amount': None, 'price_currency_code': ...
# 639  {'price_amount': None, 'price_currency_code': ...
# ...

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
# Your Code

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
# Your Code
