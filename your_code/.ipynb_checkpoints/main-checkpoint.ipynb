# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
# libraries
import pymongo
import pandas as pd

pd.options.display.max_columns = None

# connection BBDD
cliente = pymongo.MongoClient()
db = cliente['Ironhack']
col = db['companies']

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
list(col.find({"name":"Babelgum"}, {"name":1, "_id":0}))
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
cond = 5000 # condición

companies_cond = pd.DataFrame(col.find({'number_of_employees': {"$gt": cond}}).limit(20).sort("number_of_employees", -1)) # orden de mayor a menor
companies_cond.head(2)
# Out:
#                         _id     name permalink  \
# 0  52cdef7d4bab8bd67529941a  Siemens   siemens
# 1  52cdef7c4bab8bd67529856a      IBM       ibm
#
#                               crunchbase_url            homepage_url blog_url  \
# 0  http://www.crunchbase.com/company/siemens  http://www.siemens.com
# 1      http://www.crunchbase.com/company/ibm      http://www.ibm.com
#
#   blog_feed_url twitter_username category_code  number_of_employees  \
# 0                        Siemens      hardware               405000
# 1                            IBM      software               388000
#
#    founded_year  founded_month  founded_day deadpooled_year deadpooled_month  \
# 0        1847.0            NaN          NaN            None             None
# 1        1896.0            NaN          NaN            None             None
#
#   deadpooled_day deadpooled_url  \
# 0           None           None
# 1           None
#
#                                             tag_list alias_list  \
# 0  automation, building-technologies, drive-techn...
# 1
#
#          email_address     phone_number  \
# 0  contact@siemens.com  49 89 636 34134
# 1       ews@us.ibm.com     914-499-1900
#
#                               description                    created_at  \
# 0  Electronics and Electrical Engineering  Thu Jul 31 09:29:43 UTC 2008
# 1                                          Fri Mar 14 22:55:52 UTC 2008
#
#                      updated_at  \
# 0  Thu Nov 28 20:32:55 UTC 2013
# 1  Sat Jan 04 02:56:24 UTC 2014
#
#                                             overview  \
# 0  <p>Siemens AG, an electronics and electrical e...
# 1  <p>IBM, acronym for International Business Mac...
#
#                                                image  \
# 0  {'available_sizes': [[[150, 34], 'assets/image...
# 1  {'available_sizes': [[[150, 60], 'assets/image...
#
#                                             products  \
# 0                                                 []
# 1  [{'name': 'Lotus Notes', 'permalink': 'lotus-n...
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'Chairman, Superv...
# 1  [{'is_past': False, 'title': 'Chairman of the ...
#
#                                         competitions  \
# 0                                                 []
# 1  [{'competitor': {'name': 'BEA Systems', 'perma...
#
#                                        providerships total_money_raised  \
# 0  [{'title': 'Application Development', 'is_past...              $8.9M
# 1  [{'title': '', 'is_past': False, 'provider': {...                 $0
#
#                                       funding_rounds  \
# 0  [{'id': 17062, 'round_code': 'grant', 'source_...
# 1                                                 []
#
#                                          investments acquisition  \
# 0                                                 []        None
# 1  [{'funding_round': {'round_code': 'c', 'source...        None
#
#                                         acquisitions  \
# 0  [{'price_amount': 418000000, 'price_currency_c...
# 1  [{'price_amount': None, 'price_currency_code':...
#
#                                              offices  \
# 0  [{'description': '', 'address1': 'Wittelsbache...
# 1  [{'description': 'Corporate Headquarters', 'ad...
#
#                                           milestones  \
# 0  [{'id': 35852, 'description': 'Siemens Receive...
# 1  [{'id': 10471, 'description': 'IBM Completes A...
#
#                                                  ipo  \
# 0  {'valuation_amount': None, 'valuation_currency...
# 1  {'valuation_amount': None, 'valuation_currency...
#
#                                         video_embeds  \
# 0  [{'embed_code': '<iframe width="420" height="3...
# 1  [{'embed_code': '<embed src="http://blip.tv/pl...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 92], 'assets/imag...
# 1  [{'available_sizes': [[[150, 93], 'assets/imag...
#
#                                       external_links partners
# 0                                                 []       []
# 1  [{'external_url': 'http://mashpedia.com/IBM', ...       []

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
cond1 = {"founded_year":{"$gte": 2000}} # condición mayor que
cond2 = {"founded_year":{"$lte": 2005}} # condición menor que

# dataframe
filter_founded_year = pd.DataFrame(col.find({'$and': [cond1, cond2]}, {"name":1, "founded_year":1, "_id":0}). sort("founded_year", 1))
filter_founded_year.head(5)

# ordenadas por antiguedad dentro de las condiciones seleccionadas
# Out:
#        name  founded_year
# 0  AllofMP3          2000
# 1    Steorn          2000
# 2    MeeVee          2000
# 3  PhotoBox          2000
# 4    Boonex          2000

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
cond1 = {"ipo.valuation_amount":{"$gt": 100000000}} # condición valoración
cond2 = {"founded_year":{"$lt": 2010}} # condición year

# dataframe
companies_values = pd.DataFrame(col.find({'$and': [cond1, cond2]}, {"name":1, "ipo":1, "_id":0}).limit(3).sort("ipo.valuation_amount", -1))
companies_values
# Out:
#        name                                                ipo
# 0      GREE  {'valuation_amount': 108960000000, 'valuation_...
# 1  Facebook  {'valuation_amount': 104000000000, 'valuation_...
# 2    Amazon  {'valuation_amount': 100000000000, 'valuation_...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
cond1 = {"number_of_employees":{"$lt": 1000}} # condición num empleados
cond2 = {"founded_year":{"$lt": 2005}} # condición year

# dataframe
companies_values = pd.DataFrame(col.find({'$and': [cond1, cond2]}).limit(10).sort("number_of_employees", 1))
companies_values.head(2)

# ordenadas por numero de empleados de menor a mayor
# Out:
#                         _id   name permalink  \
# 0  52cdef7c4bab8bd675297dbc  Skype     skype
# 1  52cdef7c4bab8bd675298063  Simpy     simpy
#
#                             crunchbase_url          homepage_url  \
# 0  http://www.crunchbase.com/company/skype  http://www.skype.com
# 1  http://www.crunchbase.com/company/simpy  http://www.simpy.com
#
#                  blog_url                                    blog_feed_url  \
# 0  http://blogs.skype.com         http://feeds.feedburner.com/shareskypeen
# 1  http://blog.simpy.com/  http://blog.simpy.com/blojsom/blog/?flavor=rss2
#
#   twitter_username category_code  number_of_employees  founded_year  \
# 0            skype      software                    0          2003
# 1             None           web                    0          2004
#
#    founded_month  founded_day  deadpooled_year  deadpooled_month  \
# 0            8.0          NaN              NaN               NaN
# 1            5.0          1.0              NaN               NaN
#
#    deadpooled_day deadpooled_url                    tag_list alias_list  \
# 0             NaN                 phone, voip, sweden, skype
# 1             NaN           None            social-bookmarks       None
#
#   email_address phone_number     description                    created_at  \
# 0                   94117733  VoIP Software   Tue Jul 03 05:20:31 UTC 2007
# 1                                       None  Wed Oct 24 19:32:41 UTC 2007
#
#                      updated_at  \
# 0  Wed Dec 11 13:03:57 UTC 2013
# 1  Mon Mar 07 02:52:16 UTC 2011
#
#                                             overview  \
# 0  <p>Skype is a software application that allows...
# 1  <p>Simpy is a social bookmarking service. With...
#
#                                                image  \
# 0  {'available_sizes': [[[150, 66], 'assets/image...
# 1  {'available_sizes': [[[32, 32], 'assets/images...
#
#                                             products  \
# 0  [{'name': 'Skype', 'permalink': 'skype'}, {'na...
# 1          [{'name': 'Simpy', 'permalink': 'simpy'}]
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'CEO', 'person': ...
# 1  [{'is_past': True, 'title': 'Founder', 'person...
#
#                                         competitions  \
# 0  [{'competitor': {'name': 'fring Ltd', 'permali...
# 1                                                 []
#
#                                        providerships total_money_raised  \
# 0  [{'title': '', 'is_past': False, 'provider': {...             $76.8M
# 1                                                 []                 $0
#
#                                       funding_rounds  \
# 0  [{'id': 79, 'round_code': 'b', 'source_url': '...
# 1                                                 []
#
#                                          investments  \
# 0  [{'funding_round': {'round_code': 'a', 'source...
# 1                                                 []
#
#                                          acquisition  \
# 0  {'price_amount': 2600000000, 'price_currency_c...
# 1                                               None
#
#                                         acquisitions  \
# 0  [{'price_amount': 150000000, 'price_currency_c...
# 1                                                 []
#
#                                              offices  \
# 0  [{'description': 'Global HQ', 'address1': '23-...
# 1  [{'description': '', 'address1': '', 'address2...
#
#                                           milestones   ipo  \
# 0  [{'id': 552, 'description': 'Skype released pu...  None
# 1                                                 []  None
#
#                                         video_embeds  \
# 0  [{'embed_code': '<iframe src="http://blip.tv/p...
# 1                                                 []
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 130], 'assets/ima...
# 1                                                 []
#
#                                       external_links partners
# 0  [{'external_url': 'http://www.ewdn.com/2011/06...       []
# 1  [{'external_url': 'http://www.hiking-unlimited...       []

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
ne_partners = pd.DataFrame(col.find({'partners': {'$exists': True, '$ne':''}}).limit(2))
ne_partners
# Out:
#                         _id       name permalink  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint      abc2
# 1  52cdef7c4bab8bd675297d8b  AdventNet      abc3
#
#                                 crunchbase_url             homepage_url  \
# 0   http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 1  http://www.crunchbase.com/company/adventnet     http://adventnet.com
#
#                       blog_url                     blog_feed_url  \
# 0  http://digitalquarters.net/  http://digitalquarters.net/feed/
# 1
#
#   twitter_username category_code  number_of_employees  founded_year  \
# 0  BachelrWetpaint           web                   47          2005
# 1     manageengine    enterprise                  600          1996
#
#    founded_month  founded_day  deadpooled_year  \
# 0           10.0         17.0                1
# 1            NaN          NaN                2
#
#                                             tag_list          alias_list  \
# 0  wiki, seattle, elowitz, media-industry, media-...
# 1                                                     Zoho ManageEngine
#
#        email_address  phone_number                  description  \
# 0  info@wetpaint.com  206.859.6300  Technology Platform Company
# 1   pr@adventnet.com  925-924-9500   Server Management Software
#
#            created_at                    updated_at  \
# 0 2007-05-25 06:51:27  Sun Dec 08 07:15:44 UTC 2013
# 1 2007-05-25 19:24:22  Wed Oct 31 18:26:09 UTC 2012
#
#                                             overview  \
# 0  <p>Wetpaint is a technology platform company t...
# 1  <p>AdventNet is now <a href="/company/zoho-man...
#
#                                                image  \
# 0  {'available_sizes': [[[150, 75], 'assets/image...
# 1  {'available_sizes': [[[150, 55], 'assets/image...
#
#                                             products  \
# 0  [{'name': 'Wikison Wetpaint', 'permalink': 'we...
# 1                                                 []
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'Co-Founder and V...
# 1  [{'is_past': True, 'title': 'CEO and Co-Founde...
#
#                                         competitions  \
# 0  [{'competitor': {'name': 'Wikia', 'permalink':...
# 1                                                 []
#
#                                        providerships total_money_raised  \
# 0                                                 []             $39.8M
# 1  [{'title': 'DHFH', 'is_past': True, 'provider'...                 $0
#
#                                       funding_rounds investments  \
# 0  [{'id': 888, 'round_code': 'a', 'source_url': ...          []
# 1                                                 []          []
#
#                                          acquisition acquisitions  \
# 0  {'price_amount': 30000000, 'price_currency_cod...           []
# 1                                               None           []
#
#                                              offices  \
# 0  [{'description': '', 'address1': '710 - 2nd Av...
# 1  [{'description': 'Headquarters', 'address1': '...
#
#                                           milestones video_embeds  \
# 0  [{'id': 5869, 'description': 'Wetpaint named i...           []
# 1                                                 []           []
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 86], 'assets/imag...
# 1  [{'available_sizes': [[[150, 94], 'assets/imag...
#
#                                       external_links partners
# 0  [{'external_url': 'http://www.geekwire.com/201...       []
# 1                                                 []       []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
# list
list(col.find({"category_code": {"$type": "null"}}, {"_id":0, "name":1}).limit(5))
# Out:
# [{'name': 'Collective'},
#  {'name': 'Snimmer'},
#  {'name': 'KoolIM'},
#  {'name': 'Level9 Media'},
#  {'name': 'VidKing'}]

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
cond1 = {"number_of_employees":{"$gte": 100}} # condición num empleados >= 
cond2 = {"number_of_employees":{"$lte": 1000}} # condición num empleados <

# dataframe
filter_founded_year = pd.DataFrame(col.find({'$and': [cond1, cond2]}, {"name":1, "number_of_employees":1, "_id":0}). sort("number_of_employees", 1))
filter_founded_year.head(5)
# Out:
#               name  number_of_employees
# 0           Redfin                  100
# 1     Simply Hired                  100
# 2              hi5                  100
# 3  INgage Networks                  100
# 4            mig33                  100

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
top3_ipo = pd.DataFrame(col.find().limit(3).sort("ipo", -1))
top3_ipo
# Out:
#                         _id      name permalink  \
# 0  52cdef7e4bab8bd67529a8b4      GREE      gree
# 1  52cdef7c4bab8bd675297d8e  Facebook  facebook
# 2  52cdef7c4bab8bd675297e7a    Amazon    amazon
#
#                                crunchbase_url              homepage_url  \
# 0      http://www.crunchbase.com/company/gree  http://www.gree-corp.com
# 1  http://www.crunchbase.com/company/facebook       http://facebook.com
# 2    http://www.crunchbase.com/company/amazon         http://amazon.com
#
#                    blog_url                      blog_feed_url  \
# 0
# 1  http://blog.facebook.com  http://blog.facebook.com/atom.php
# 2
#
#   twitter_username category_code  number_of_employees  founded_year  \
# 0        gree_corp   games_video                700.0          2004
# 1         facebook        social               5299.0          2004
# 2           amazon     ecommerce                  NaN          1994
#
#    founded_month  founded_day deadpooled_year deadpooled_month deadpooled_day  \
# 0           12.0          7.0            None             None           None
# 1            2.0          1.0            None             None           None
# 2            NaN          NaN            None             None           None
#
#   deadpooled_url                                           tag_list  \
# 0           None  mobile-web, japan, tokyo, social-network, mobi...
# 1                 facebook, college, students, profiles, network...
# 2           None  virtualstorage, onlineshopping, virtualserver,...
#
#   alias_list          email_address    phone_number  \
# 0       None  inquiry@gree-corp.com
# 1
# 2                                    (206) 266-1000
#
#                                description                    created_at  \
# 0  Internet media business,SNS,  free game  Sat Dec 20 16:42:57 UTC 2008
# 1                           Social network  Fri May 25 21:22:15 UTC 2007
# 2                                           Tue Jul 31 06:46:49 UTC 2007
#
#                      updated_at  \
# 0  Tue Jan 01 21:37:04 UTC 2013
# 1  Thu Nov 21 19:40:55 UTC 2013
# 2  Wed Oct 30 17:13:43 UTC 2013
#
#                                             overview  \
# 0  <p>GREE provides Japan&#8217;s leading mobile ...
# 1  <p>Facebook is the world&#8217;s largest socia...
# 2  <p>Amazon.com, Inc. (AMZN), is a leading globa...
#
#                                                image  \
# 0  {'available_sizes': [[[150, 61], 'assets/image...
# 1  {'available_sizes': [[[150, 61], 'assets/image...
# 2  {'available_sizes': [[[150, 66], 'assets/image...
#
#                                             products  \
# 0                                                 []
# 1  [{'name': 'Facebook Platform', 'permalink': 'f...
# 2  [{'name': 'Amazon EC2', 'permalink': 'amazon-e...
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'CEO', 'person': ...
# 1  [{'is_past': False, 'title': 'Founder and CEO,...
# 2  [{'is_past': False, 'title': 'Founder, Preside...
#
#                                         competitions  \
# 0  [{'competitor': {'name': 'Mobage-town', 'perma...
# 1  [{'competitor': {'name': 'MySpace', 'permalink...
# 2  [{'competitor': {'name': 'eMusic', 'permalink'...
#
#                                        providerships total_money_raised  \
# 0                                                 []              ¥464M
# 1  [{'title': '', 'is_past': False, 'provider': {...             $2.43B
# 2  [{'title': '', 'is_past': False, 'provider': {...                $8M
#
#                                       funding_rounds  \
# 0  [{'id': 18872, 'round_code': 'unattributed', '...
# 1  [{'id': 2, 'round_code': 'angel', 'source_url'...
# 2  [{'id': 24535, 'round_code': 'a', 'source_url'...
#
#                                          investments acquisition  \
# 0  [{'funding_round': {'round_code': 'seed', 'sou...        None
# 1  [{'funding_round': {'round_code': 'seed', 'sou...        None
# 2  [{'funding_round': {'round_code': 'seed', 'sou...        None
#
#                                         acquisitions  \
# 0  [{'price_amount': 104000000, 'price_currency_c...
# 1  [{'price_amount': None, 'price_currency_code':...
# 2  [{'price_amount': None, 'price_currency_code':...
#
#                                              offices  \
# 0  [{'description': 'Headquarters', 'address1': '...
# 1  [{'description': 'Headquarters', 'address1': '...
# 2  [{'description': None, 'address1': '1200 12th ...
#
#                                           milestones  \
# 0  [{'id': 1021, 'description': 'IPO', 'stoned_ye...
# 1  [{'id': 108, 'description': 'Facebook adds com...
# 2  [{'id': 6931, 'description': 'How Many Kindle ...
#
#                                                  ipo  \
# 0  {'valuation_amount': 108960000000, 'valuation_...
# 1  {'valuation_amount': 104000000000, 'valuation_...
# 2  {'valuation_amount': 100000000000, 'valuation_...
#
#                                         video_embeds  \
# 0                                                 []
# 1                                                 []
# 2  [{'embed_code': '<object width="425" height="3...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[133, 150], 'assets/ima...
# 1  [{'available_sizes': [[[150, 68], 'assets/imag...
# 2  [{'available_sizes': [[[150, 94], 'assets/imag...
#
#                                       external_links partners
# 0                                                 []       []
# 1  [{'external_url': 'http://latimesblogs.latimes...       []
# 2                                                 []       []

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
filter_employees_num = pd.DataFrame(col.find().limit(10).sort("number_of_employees", -1)) # orden de mayor a menor
filter_employees_num.head(3)
# Out:
#                         _id     name permalink  \
# 0  52cdef7d4bab8bd67529941a  Siemens   siemens
# 1  52cdef7c4bab8bd67529856a      IBM       ibm
# 2  52cdef7d4bab8bd675299d33   Toyota    toyota
#
#                               crunchbase_url                  homepage_url  \
# 0  http://www.crunchbase.com/company/siemens        http://www.siemens.com
# 1      http://www.crunchbase.com/company/ibm            http://www.ibm.com
# 2   http://www.crunchbase.com/company/toyota  http://www.toyota-global.com
#
#   blog_url blog_feed_url twitter_username category_code  number_of_employees  \
# 0                                 Siemens      hardware               405000
# 1                                     IBM      software               388000
# 2                                  Toyota    enterprise               320000
#
#    founded_year  founded_month  founded_day deadpooled_year deadpooled_month  \
# 0          1847            NaN          NaN            None             None
# 1          1896            NaN          NaN            None             None
# 2          1933            NaN          NaN            None             None
#
#   deadpooled_day deadpooled_url  \
# 0           None           None
# 1           None
# 2           None           None
#
#                                             tag_list alias_list  \
# 0  automation, building-technologies, drive-techn...
# 1
# 2                                               None
#
#          email_address     phone_number  \
# 0  contact@siemens.com  49 89 636 34134
# 1       ews@us.ibm.com     914-499-1900
# 2                        81 5 6528 2121
#
#                               description                    created_at  \
# 0  Electronics and Electrical Engineering  Thu Jul 31 09:29:43 UTC 2008
# 1                                          Fri Mar 14 22:55:52 UTC 2008
# 2                              Automotive  Mon Sep 22 22:00:26 UTC 2008
#
#                      updated_at  \
# 0  Thu Nov 28 20:32:55 UTC 2013
# 1  Sat Jan 04 02:56:24 UTC 2014
# 2  Mon Nov 11 16:24:21 UTC 2013
#
#                                             overview  \
# 0  <p>Siemens AG, an electronics and electrical e...
# 1  <p>IBM, acronym for International Business Mac...
# 2  <p>Toyota operates 75 manufacturing companies ...
#
#                                                image  \
# 0  {'available_sizes': [[[150, 34], 'assets/image...
# 1  {'available_sizes': [[[150, 60], 'assets/image...
# 2  {'available_sizes': [[[135, 37], 'assets/image...
#
#                                             products  \
# 0                                                 []
# 1  [{'name': 'Lotus Notes', 'permalink': 'lotus-n...
# 2                                                 []
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'Chairman, Superv...
# 1  [{'is_past': False, 'title': 'Chairman of the ...
# 2  [{'is_past': False, 'title': '', 'person': {'f...
#
#                                         competitions  \
# 0                                                 []
# 1  [{'competitor': {'name': 'BEA Systems', 'perma...
# 2                                                 []
#
#                                        providerships total_money_raised  \
# 0  [{'title': 'Application Development', 'is_past...              $8.9M
# 1  [{'title': '', 'is_past': False, 'provider': {...                 $0
# 2  [{'title': '', 'is_past': True, 'provider': {'...                 $0
#
#                                       funding_rounds  \
# 0  [{'id': 17062, 'round_code': 'grant', 'source_...
# 1                                                 []
# 2                                                 []
#
#                                          investments acquisition  \
# 0                                                 []        None
# 1  [{'funding_round': {'round_code': 'c', 'source...        None
# 2  [{'funding_round': {'round_code': 'a', 'source...        None
#
#                                         acquisitions  \
# 0  [{'price_amount': 418000000, 'price_currency_c...
# 1  [{'price_amount': None, 'price_currency_code':...
# 2                                                 []
#
#                                              offices  \
# 0  [{'description': '', 'address1': 'Wittelsbache...
# 1  [{'description': 'Corporate Headquarters', 'ad...
# 2  [{'description': 'HQ', 'address1': 'Toyota Mot...
#
#                                           milestones  \
# 0  [{'id': 35852, 'description': 'Siemens Receive...
# 1  [{'id': 10471, 'description': 'IBM Completes A...
# 2                                                 []
#
#                                                  ipo  \
# 0  {'valuation_amount': None, 'valuation_currency...
# 1  {'valuation_amount': None, 'valuation_currency...
# 2                                               None
#
#                                         video_embeds  \
# 0  [{'embed_code': '<iframe width="420" height="3...
# 1  [{'embed_code': '<embed src="http://blip.tv/pl...
# 2  [{'embed_code': '<iframe width="430" height="3...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 92], 'assets/imag...
# 1  [{'available_sizes': [[[150, 93], 'assets/imag...
# 2  [{'available_sizes': [[[150, 84], 'assets/imag...
#
#                                       external_links partners
# 0                                                 []       []
# 1  [{'external_url': 'http://mashpedia.com/IBM', ...       []
# 2                                                 []       []

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
cond1 = {"founded_month":{"$gte": 6}}
cond2 = {"founded_month":{"$lte": 12}}

# dataframe
filter_founded_month = pd.DataFrame(col.find({'$and': [cond1, cond2]}, {"name":1, "founded_month":1, "_id":0}).limit(1000))
filter_founded_month.head(5)
# Out:
#         name  founded_month
# 0   Wetpaint             10
# 1       Zoho              9
# 2       Digg             10
# 3  Omnidrive             11
# 4    Postini              6

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
cond1 = {"founded_year":{"$lt": 2000}}
cond2 = {"acquisition.price_amount":{"$gt": 10000}}

# dataframe
filter_lt2000 = pd.DataFrame(col.find({'$and': [cond1, cond2]}).limit(10).sort("acquisition.price_amount", -1))
filter_lt2000.head(2)
# Out:
#                         _id         name    permalink  \
# 0  52cdef7c4bab8bd6752983f8  BEA Systems  bea-systems
# 1  52cdef7d4bab8bd675299e35       Navteq       navteq
#
#                                   crunchbase_url           homepage_url  \
# 0  http://www.crunchbase.com/company/bea-systems     http://www.bea.com
# 1       http://www.crunchbase.com/company/navteq  http://www.navteq.com
#
#   blog_url blog_feed_url twitter_username category_code  number_of_employees  \
# 0                                    None      software                  NaN
# 1                                              software                  NaN
#
#    founded_year  founded_month  founded_day deadpooled_year deadpooled_month  \
# 0          1995            NaN          NaN            None             None
# 1          1985            NaN          NaN            None             None
#
#   deadpooled_day deadpooled_url tag_list               alias_list  \
# 0           None           None     None                     None
# 1           None           None     None  Navigation Technologies
#
#   email_address    phone_number                   description  \
# 0                1-800-817-4BEA                          None
# 1                  312-894-7000  location data for navigation
#
#                      created_at                    updated_at  \
# 0  Thu Feb 28 04:44:54 UTC 2008  Wed Oct 03 00:09:52 UTC 2012
# 1  Wed Oct 01 00:08:51 UTC 2008  Fri Aug 03 19:06:50 UTC 2012
#
#                                             overview  \
# 0  <p>BEA is a leading provider of enterprise sof...
# 1  <p>NAVTEQ Corporation develops and delivers di...
#
#                                                image  \
# 0  {'available_sizes': [[[96, 85], 'assets/images...
# 1  {'available_sizes': [[[150, 33], 'assets/image...
#
#                                             products  \
# 0  [{'name': 'BEA Aqualogic', 'permalink': 'bea-a...
# 1                                                 []
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'Founder', 'perso...
# 1  [{'is_past': False, 'title': 'Senior Product A...
#
#                                         competitions providerships  \
# 0  [{'competitor': {'name': 'IBM', 'permalink': '...            []
# 1                                                 []            []
#
#   total_money_raised funding_rounds  \
# 0                 $0             []
# 1                 $0             []
#
#                                          investments  \
# 0                                                 []
# 1  [{'funding_round': {'round_code': 'b', 'source...
#
#                                          acquisition  \
# 0  {'price_amount': 8500000000, 'price_currency_c...
# 1  {'price_amount': 8100000000, 'price_currency_c...
#
#                                         acquisitions  \
# 0                                                 []
# 1  [{'price_amount': None, 'price_currency_code':...
#
#                                              offices milestones   ipo  \
# 0  [{'description': '', 'address1': '', 'address2...         []  None
# 1  [{'description': 'HQ', 'address1': '425 West R...         []  None
#
#   video_embeds                                        screenshots  \
# 0           []                                                 []
# 1           []  [{'available_sizes': [[[150, 89], 'assets/imag...
#
#   external_links partners
# 0             []       []
# 1             []       []

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
cond = 2010 # condición year

# dataframe
filter_gt2010 = pd.DataFrame(col.find({"acquisition.acquired_year":{"$gt": cond}}, {"name":1, "acquisition":1, "_id":0}).limit(10).sort("acquisition.price_amount", -1))
filter_gt2010.head(6)
# Out:
#                      name                                        acquisition
# 0                T-Mobile  {'price_amount': 39000000000, 'price_currency_...
# 1    Goodrich Corporation  {'price_amount': 18400000000, 'price_currency_...
# 2                     LSI  {'price_amount': 6600000000, 'price_currency_c...
# 3  National Semiconductor  {'price_amount': 6500000000, 'price_currency_c...
# 4                   Ariba  {'price_amount': 4300000000, 'price_currency_c...
# 5   NetLogic Microsystems  {'price_amount': 3700000000, 'price_currency_c...

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
# dataframe
founded_year = pd.DataFrame(col.find({},{"name":1, "founded_year":1, "_id":0}).limit(10).sort("founded_year", -1))
founded_year.head(4)
# Out:
#      name  founded_year
# 0   Wamba          2013
# 1  Gimigo          2013
# 2  Clowdy          2013
# 3   Fixya          2013

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
cond = 7 #condición day of month

# dataframe
founded_day = pd.DataFrame(col.find({'founded_day': {'$lte': cond}}).limit(10).sort("acquisition.price_amount", -1))
founded_day.head(2)
# Out:
#                         _id      name permalink  \
# 0  52cdef7d4bab8bd6752989a1  Netscape  netscape
# 1  52cdef7c4bab8bd675297e89    PayPal    paypal
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/netscape  http://netscape.aol.com
# 1    http://www.crunchbase.com/company/paypal    http://www.paypal.com
#
#   blog_url blog_feed_url twitter_username category_code  number_of_employees  \
# 0                                              software                  NaN
# 1                                  paypal       finance             300000.0
#
#    founded_year  founded_month  founded_day  deadpooled_year  \
# 0          1994              4            4              NaN
# 1          1998             12            1              NaN
#
#    deadpooled_month  deadpooled_day deadpooled_url  \
# 0               NaN             NaN           None
# 1               NaN             NaN           None
#
#                                             tag_list alias_list email_address  \
# 0                                               None
# 1  moneytransfer, crunchbase, ecommerce, paypal, ...
#
#    phone_number               description                    created_at  \
# 0                                          Tue May 06 00:27:28 UTC 2008
# 1  207-619-2873  Internet payment service  Wed Aug 01 09:16:46 UTC 2007
#
#                      updated_at  \
# 0  Thu Nov 14 00:57:06 UTC 2013
# 1  Fri Dec 20 04:43:53 UTC 2013
#
#                                             overview  \
# 0  <p>Netscape Communications Corporation offers ...
# 1  <p>PayPal is an online payments and money tran...
#
#                                                image  \
# 0  {'available_sizes': [[[150, 40], 'assets/image...
# 1  {'available_sizes': [[[150, 51], 'assets/image...
#
#                                             products  \
# 0                                                 []
# 1  [{'name': 'PayPal Here', 'permalink': 'paypal-...
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'Chief Scientist'...
# 1  [{'is_past': False, 'title': 'Vice President, ...
#
#                                         competitions  \
# 0                                                 []
# 1  [{'competitor': {'name': 'KushCash', 'permalin...
#
#                                        providerships total_money_raised  \
# 0                                                 []                 $0
# 1  [{'title': 'Public Relations', 'is_past': True...              $197M
#
#                                       funding_rounds  \
# 0  [{'id': 20468, 'round_code': 'c', 'source_url'...
# 1  [{'id': 284, 'round_code': 'd', 'source_url': ...
#
#                                          investments  \
# 0                                                 []
# 1  [{'funding_round': {'round_code': 'c', 'source...
#
#                                          acquisition  \
# 0  {'price_amount': 4200000000, 'price_currency_c...
# 1  {'price_amount': 1500000000, 'price_currency_c...
#
#                                         acquisitions  \
# 0                                                 []
# 1  [{'price_amount': None, 'price_currency_code':...
#
#                                              offices  \
# 0  [{'description': '', 'address1': '466 Ellis St...
# 1  [{'description': '', 'address1': '2145 E Hamil...
#
#                                           milestones   ipo video_embeds  \
# 0                                                 []  None           []
# 1  [{'id': 11916, 'description': 'Reserve Bank Of...  None           []
#
#                                          screenshots  \
# 0                                                 []
# 1  [{'available_sizes': [[[150, 120], 'assets/ima...
#
#                                       external_links partners
# 0                                                 []       []
# 1  [{'external_url': 'http://www.sociableblog.com...       []

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
cond1 = {"category_code":{"$eq": "web"}} # condición categoria
cond2 = {"number_of_employees":{"$gt": 4000}} # condición num empleados

# dataframe
filter_category = pd.DataFrame(col.find({'$and': [cond1, cond2]}).limit(10).sort("number_of_employees", 1))
filter_category.head(2)
# Out:
#                         _id     name permalink  \
# 0  52cdef7c4bab8bd67529822a  Expedia   expedia
# 1  52cdef7c4bab8bd675297e96      AOL       aol
#
#                               crunchbase_url            homepage_url  \
# 0  http://www.crunchbase.com/company/expedia  http://www.expedia.com
# 1      http://www.crunchbase.com/company/aol      http://www.aol.com
#
#                blog_url                                   blog_feed_url  \
# 0
# 1  http://blog.aol.com/  http://feeds.feedburner.com/AolBlog?format=xml
#
#   twitter_username category_code  number_of_employees  founded_year  \
# 0          Expedia           web                 4400          1996
# 1              aol           web                 8000          1985
#
#    founded_month  founded_day deadpooled_year deadpooled_month deadpooled_day  \
# 0            NaN          NaN            None             None           None
# 1            5.0         24.0            None             None           None
#
#   deadpooled_url                                           tag_list  \
# 0           None  travel, flights, hotels, tickets, airline, vac...
# 1                                  american-on-line, america-online
#
#                         alias_list email_address     phone_number description  \
# 0                                                   1-800-EXPEDIA
# 1  America Online, America on-line                +1-703-265-1000
#
#                      created_at                    updated_at  \
# 0  Sun Feb 10 03:29:12 UTC 2008  Sun Dec 08 07:03:33 UTC 2013
# 1  Fri Aug 03 06:26:04 UTC 2007  Fri Nov 29 21:51:48 UTC 2013
#
#                                             overview  \
# 0  <p>Expedia.com is an Internet-based travel age...
# 1  <p>AOL is a global advertising-supported Web c...
#
#                                                image  \
# 0  {'available_sizes': [[[150, 115], 'assets/imag...
# 1  {'available_sizes': [[[150, 84], 'assets/image...
#
#                                             products  \
# 0                                                 []
# 1  [{'name': 'Xdrive', 'permalink': 'xdrive'}, {'...
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'Director and Vic...
# 1  [{'is_past': False, 'title': 'CEO, Chairman', ...
#
#                                         competitions  \
# 0  [{'competitor': {'name': 'Farecast', 'permalin...
# 1  [{'competitor': {'name': 'MySpace', 'permalink...
#
#                                        providerships total_money_raised  \
# 0  [{'title': '', 'is_past': False, 'provider': {...                 $0
# 1                                                 []                $1B
#
#                                       funding_rounds  \
# 0                                                 []
# 1  [{'id': 3548, 'round_code': 'post_ipo_equity',...
#
#                                          investments  \
# 0  [{'funding_round': {'round_code': 'c', 'source...
# 1  [{'funding_round': {'round_code': 'b', 'source...
#
#                                          acquisition  \
# 0  {'price_amount': None, 'price_currency_code': ...
# 1                                               None
#
#                                         acquisitions  \
# 0  [{'price_amount': None, 'price_currency_code':...
# 1  [{'price_amount': 40000000, 'price_currency_co...
#
#                                              offices  \
# 0  [{'description': 'Corporate Office', 'address1...
# 1  [{'description': 'HQ', 'address1': '770 Broadw...
#
#                                           milestones  \
# 0  [{'id': 11691, 'description': 'US AIRWAYS AND ...
# 1  [{'id': 2689, 'description': 'AOL relauches, c...
#
#                                                  ipo  \
# 0  {'valuation_amount': None, 'valuation_currency...
# 1  {'valuation_amount': None, 'valuation_currency...
#
#                                         video_embeds  \
# 0                                                 []
# 1  [{'embed_code': '<embed src="http://blip.tv/pl...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 93], 'assets/imag...
# 1  [{'available_sizes': [[[150, 91], 'assets/imag...
#
#                                       external_links partners
# 0  [{'external_url': 'http://www.urlaubs-rabatte....       []
# 1  [{'external_url': 'http://mashpedia.com/AOL', ...       []

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
cond1 = {"acquisition.price_amount":{"$gt": 10000000}} # condición importe
cond2 = {"acquisition.price_currency_code":{"$eq": "EUR"}} # condición tipo de moneda

# dataframe
filter_price2 = pd.DataFrame(col.find({'$and': [cond1, cond2]}).limit(10).sort("acquisition.price_amount", -1))
filter_price2.head(2)
# Out:
#                         _id     name permalink  \
# 0  52cdef7d4bab8bd675298bf3  Apertio   apertio
# 1  52cdef7e4bab8bd67529a536  Webedia   webedia
#
#                               crunchbase_url            homepage_url blog_url  \
# 0  http://www.crunchbase.com/company/apertio  http://www.apertio.com
# 1  http://www.crunchbase.com/company/webedia   http://purepeople.com
#
#                    blog_feed_url twitter_username category_code  \
# 0                                            None        mobile
# 1  http://www.purepeople.com/rss       purepeople           web
#
#    number_of_employees  founded_year  founded_month  founded_day  \
# 0                  NaN           NaN            NaN          NaN
# 1                 50.0        2007.0           11.0          1.0
#
#   deadpooled_year deadpooled_month deadpooled_day deadpooled_url  \
# 0            None             None           None           None
# 1            None             None           None           None
#
#             tag_list alias_list            email_address  phone_number  \
# 0                          None
# 1  web, news, people             redaction@purepeople.fr  +33156799102
#
#   description                    created_at                    updated_at  \
# 0        None  Tue May 27 07:08:56 UTC 2008  Fri Aug 28 23:39:22 UTC 2009
# 1              Sat Nov 29 18:18:06 UTC 2008  Fri May 24 07:18:38 UTC 2013
#
#                                             overview  \
# 0  <p>Apertio One provides a single, open, subscr...
# 1  <p>The reference site on the news of the stars...
#
#                                                image products  \
# 0  {'available_sizes': [[[150, 41], 'assets/image...       []
# 1  {'available_sizes': [[[150, 37], 'assets/image...       []
#
#                                        relationships competitions  \
# 0  [{'is_past': True, 'title': 'VP Business Devel...           []
# 1  [{'is_past': False, 'title': 'Board', 'person'...           []
#
#   providerships total_money_raised  \
# 0            []               $30M
# 1            []                 $0
#
#                                       funding_rounds investments  \
# 0  [{'id': 2405, 'round_code': 'b', 'source_url':...          []
# 1                                                 []          []
#
#                                          acquisition acquisitions  \
# 0  {'price_amount': 140000000, 'price_currency_co...           []
# 1  {'price_amount': 70000000, 'price_currency_cod...           []
#
#                                              offices milestones   ipo  \
# 0  [{'description': None, 'address1': '', 'addres...         []  None
# 1  [{'description': '', 'address1': '', 'address2...         []  None
#
#   video_embeds                                        screenshots  \
# 0           []                                                 []
# 1           []  [{'available_sizes': [[[150, 93], 'assets/imag...
#
#   external_links partners
# 0             []       []
# 1             []       []

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
cond = 4 # condición month

# dataframe
top3_acquired3 = pd.DataFrame(col.find({"acquisition.acquired_month":{"$lt": cond}}, {"name":1, "acquisition":1, "_id":0}).limit(10).sort("acquisition.price_amount", -1))
top3_acquired3.head(3)
# Out:
#            name                                        acquisition
# 0      T-Mobile  {'price_amount': 39000000000, 'price_currency_...
# 1   BEA Systems  {'price_amount': 8500000000, 'price_currency_c...
# 2  Puget Energy  {'price_amount': 7400000000, 'price_currency_c...

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
df = pd.DataFrame(col.find())

df['filter_deadpooled'] = df["deadpooled_year"] - df["founded_year"]

df[df['filter_deadpooled'] > 3].head(3)
# Out:
#                          _id      name permalink  \
# 22  52cdef7c4bab8bd675297da0  Babelgum  babelgum
# 36  52cdef7c4bab8bd675297dae     Thoof     thoof
# 44  52cdef7c4bab8bd675297db6    Wesabe    wesabe
#
#                                 crunchbase_url         homepage_url  \
# 22  http://www.crunchbase.com/company/babelgum  http://babelgum.com
# 36     http://www.crunchbase.com/company/thoof     http://thoof.com
# 44    http://www.crunchbase.com/company/wesabe    http://wesabe.com
#
#                     blog_url                         blog_feed_url  \
# 22  http://babelgum.com/blog  http://feeds.feedburner.com/Babelgum
# 36                                                            None
# 44   http://blog.wesabe.com/          http://blog.wesabe.com/feed/
#
#    twitter_username category_code  number_of_employees  founded_year  \
# 22         Babelgum   games_video                  NaN        2007.0
# 36             None           web                  NaN        2006.0
# 44        jasonlong           web                  NaN        2005.0
#
#     founded_month  founded_day  deadpooled_year  \
# 22            3.0          1.0           2013.0
# 36           12.0          1.0           2013.0
# 44           12.0          1.0           2010.0
#
#                            tag_list alias_list       email_address  \
# 22                iptv, web2ireland              info@babelgum.com
# 36                      social-news       None                None
# 44  moneymanagement, finance, money       None  contact@wesabe.com
#
#    phone_number description                    created_at  \
# 22                           Sat Jun 09 08:15:21 UTC 2007
# 36         None        None  Sat Jun 16 05:05:50 UTC 2007
# 44         None        None  Wed Jun 20 10:59:01 UTC 2007
#
#                       updated_at  \
# 22  Wed Oct 16 06:30:25 UTC 2013
# 36  Wed Dec 18 13:06:44 UTC 2013
# 44  Fri Apr 15 01:40:13 UTC 2011
#
#                                              overview  \
# 22  <p>Babelgum is an integrated web and mobile vi...
# 36  <p>Thoof is a late entry to the personalized/s...
# 44  <p>JF11V8 You&#8217;ve hit the ball out the pa...
#
#                                                 image  \
# 22  {'available_sizes': [[[135, 102], 'assets/imag...
# 36  {'available_sizes': [[[150, 74], 'assets/image...
# 44  {'available_sizes': [[[129, 133], 'assets/imag...
#
#                                            products  \
# 22  [{'name': 'Babelgum', 'permalink': 'babelgum'}]
# 36        [{'name': 'Thoof', 'permalink': 'thoof'}]
# 44      [{'name': 'Wesabe', 'permalink': 'wesabe'}]
#
#                                         relationships  \
# 22  [{'is_past': False, 'title': 'CEO', 'person': ...
# 36  [{'is_past': True, 'title': 'Founder and CEO',...
# 44  [{'is_past': False, 'title': 'Co-Founder and C...
#
#                                          competitions providerships  \
# 22  [{'competitor': {'name': 'Joost', 'permalink':...            []
# 36  [{'competitor': {'name': 'Last.fm', 'permalink...            []
# 44  [{'competitor': {'name': 'Revolution Money', '...            []
#
#    total_money_raised                                     funding_rounds  \
# 22             $13.2M  [{'id': 17, 'round_code': 'a', 'source_url': '...
# 36                $1M  [{'id': 35, 'round_code': 'seed', 'source_url'...
# 44              $4.7M  [{'id': 43, 'round_code': 'seed', 'source_url'...
#
#    investments acquisition acquisitions  \
# 22          []        None           []
# 36          []        None           []
# 44          []        None           []
#
#                                               offices milestones  \
# 22  [{'description': '', 'address1': '', 'address2...         []
# 36  [{'description': None, 'address1': None, 'addr...         []
# 44  [{'description': None, 'address1': '400 Montgo...         []
#
#                                          video_embeds screenshots  \
# 22                                                 []          []
# 36                                                 []          []
# 44  [{'embed_code': '<script src="http://flash.rev...          []
#
#                                        external_links partners  \
# 22                                                 []       []
# 36  [{'external_url': 'http://www.duraslide.com.sg...       []
# 44                                                 []       []
#
#     deadpooled_month  deadpooled_day  \
# 22               1.0             9.0
# 36               8.0             4.0
# 44               6.0            30.0
#
#                                        deadpooled_url   ipo  filter_deadpooled
# 22                                                     None                6.0
# 36                                                     None                7.0
# 44  http://techcrunch.com/2010/06/30/wesabe-shuts-...  None                5.0
